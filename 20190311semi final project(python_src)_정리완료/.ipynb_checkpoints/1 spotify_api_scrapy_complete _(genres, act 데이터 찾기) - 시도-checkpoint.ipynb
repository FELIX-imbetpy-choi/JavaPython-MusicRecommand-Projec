# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

cid ="18036c9769a64a9488a17419863beb3b" 
secret = "6dfa96c4f860468f8bf4a796e2b90df6"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# timeit library to measure the time needed to run this code
import timeit
start = timeit.default_timer()

# create empty lists where the results are going to be stored
artist_name = []
track_name = []
popularity = []
track_id = []
spotify_href = []
images = []
release_date = []

for i in range(0,10000,50):
    track_results = sp.search(q='year:2005', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        spotify_href.append(t['external_urls']['spotify'])
        try:
            images.append(t['album']['images'][0]['url'])
        except:
            images.append('')
        release_date.append(t['album']['release_date'])
            
stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
# Out:
# retrying ...1secs
# Time to run this code (in seconds): 125.99384097000001

# %%
# 곡의 장르 정보는 존재하지 않는다.
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2005&type=track&offset=9950&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#        'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#        'id': '5aIqB5nVVvmFsvSdExz408',
#        'name': 'Johann Sebastian Bach',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3f26hJvBDQnllvH0aP4OSb'},
#        'href': 'https://api.spotify.com/v1/artists/3f26hJvBDQnllvH0aP4OSb',
#        'id': '3f26hJvBDQnllvH0aP4OSb',
#        'name': 'Concerto Italiano',
#        'type': 'artist',
#        'uri': 'spotify:artist:3f26hJvBDQnllvH0aP4OSb'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1CqIIrCkdFMduTzAdIaeZb'},
#        'href': 'https://api.spotify.com/v1/artists/1CqIIrCkdFMduTzAdIaeZb',
#        'id': '1CqIIrCkdFMduTzAdIaeZb',
#        'name': 'Rinaldo Alessandrini',
#        'type': 'artist',
#        'uri': 'spotify:artist:1CqIIrCkdFMduTzAdIaeZb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2NhE2dSSUEEH4oAOVMCFaH'},
#      'href': 'https://api.spotify.com/v1/albums/2NhE2dSSUEEH4oAOVMCFaH',
#      'id': '2NhE2dSSUEEH4oAOVMCFaH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/a35e8b8e4742a5ad521690110273c16a2281f954',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/fde33235fe1a0a41d1938989d83941ecc2df2031',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/27fb3821567931797c64b6eab9926bf20d937c9c',
#        'width': 64}],
#      'name': 'Bach: Brandenburg Concertos',
#      'release_date': '2005',
#      'release_date_precision': 'year',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:2NhE2dSSUEEH4oAOVMCFaH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1CqIIrCkdFMduTzAdIaeZb'},
#       'href': 'https://api.spotify.com/v1/artists/1CqIIrCkdFMduTzAdIaeZb',
#       'id': '1CqIIrCkdFMduTzAdIaeZb',
#       'name': 'Rinaldo Alessandrini',
#       'type': 'artist',
#       'uri': 'spotify:artist:1CqIIrCkdFMduTzAdIaeZb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3f26hJvBDQnllvH0aP4OSb'},
#       'href': 'https://api.spotify.com/v1/artists/3f26hJvBDQnllvH0aP4OSb',
#       'id': '3f26hJvBDQnllvH0aP4OSb',
#       'name': 'Concerto Italiano',
#       'type': 'artist',
#       'uri': 'spotify:artist:3f26hJvBDQnllvH0aP4OSb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 260346,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRX290500242'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0f1Mgnl24tDeGshwKScQKn'},
#     'href': 'https://api.spotify.com/v1/tracks/0f1Mgnl24tDeGshwKScQKn',
#     'id': '0f1Mgnl24tDeGshwKScQKn',
#     'is_local': False,
#     'name': 'Six Brandenburg Concertos, No. 3 in G Major, BWV1048: II. Adagio & III. Allegro',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/997e1fcae62809e59e84fceff039c93718650780?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:0f1Mgnl24tDeGshwKScQKn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IRgZYuKlqlD3BCEhb52ne'},
#        'href': 'https://api.spotify.com/v1/artists/4IRgZYuKlqlD3BCEhb52ne',
#        'id': '4IRgZYuKlqlD3BCEhb52ne',
#        'name': 'Chelo',
#        'type': 'artist',
#        'uri': 'spotify:artist:4IRgZYuKlqlD3BCEhb52ne'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ZUpHsO3z5yERu4mxDQHxd'},
#      'href': 'https://api.spotify.com/v1/albums/4ZUpHsO3z5yERu4mxDQHxd',
#      'id': '4ZUpHsO3z5yERu4mxDQHxd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/09488edb691315df75090584328e095efd9b2576',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7ba26db23ca35a996b324cd4b86a011ca52e7795',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/d20ca6c91da37068bd8d8f0ded90b1385ef46e33',
#        'width': 64}],
#      'name': 'Mi Historia - Chelo',
#      'release_date': '2005-08-12',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:4ZUpHsO3z5yERu4mxDQHxd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IRgZYuKlqlD3BCEhb52ne'},
#       'href': 'https://api.spotify.com/v1/artists/4IRgZYuKlqlD3BCEhb52ne',
#       'id': '4IRgZYuKlqlD3BCEhb52ne',
#       'name': 'Chelo',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IRgZYuKlqlD3BCEhb52ne'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212381,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF367623291'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0qPGsdMGR7pKpxTyDCCXmL'},
#     'href': 'https://api.spotify.com/v1/tracks/0qPGsdMGR7pKpxTyDCCXmL',
#     'id': '0qPGsdMGR7pKpxTyDCCXmL',
#     'is_local': False,
#     'name': 'Mejor Me Voy',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0b3ce933a0a29764f7ffe4ea47e56d35ecb6ae03?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0qPGsdMGR7pKpxTyDCCXmL'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05p1Vs5NCSokqYvxowV7By'},
#        'href': 'https://api.spotify.com/v1/artists/05p1Vs5NCSokqYvxowV7By',
#        'id': '05p1Vs5NCSokqYvxowV7By',
#        'name': 'Dire Straits & Mark Knopfler',
#        'type': 'artist',
#        'uri': 'spotify:artist:05p1Vs5NCSokqYvxowV7By'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/37LUBeVwoGFQOvBhRPNV13'},
#      'href': 'https://api.spotify.com/v1/albums/37LUBeVwoGFQOvBhRPNV13',
#      'id': '37LUBeVwoGFQOvBhRPNV13',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/d938d8a7a477b6d251b9932e04b9520df54ce82a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/39a851fa52a6abd3c6c55c028298c89f7dd8606d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/6fd21a90b13414058cfbdf52aa665d1345eab3bf',
#        'width': 64}],
#      'name': 'The Best Of - Private Investigations',
#      'release_date': '2005-11-15',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:37LUBeVwoGFQOvBhRPNV13'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T'},
#       'href': 'https://api.spotify.com/v1/artists/0WwSkZ7LtFUFjGjMZBMt6T',
#       'id': '0WwSkZ7LtFUFjGjMZBMt6T',
#       'name': 'Dire Straits',
#       'type': 'artist',
#       'uri': 'spotify:artist:0WwSkZ7LtFUFjGjMZBMt6T'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 360000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10505256'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0r7CZrmB1vvPHIoKN0E6iA'},
#     'href': 'https://api.spotify.com/v1/tracks/0r7CZrmB1vvPHIoKN0E6iA',
#     'id': '0r7CZrmB1vvPHIoKN0E6iA',
#     'is_local': False,
#     'name': 'Romeo and Juliet',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0be037de98b1d6b590551b8eb3300cea069f65e3?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0r7CZrmB1vvPHIoKN0E6iA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5p9CTsn5ueGU4oScNX1axu'},
#        'href': 'https://api.spotify.com/v1/artists/5p9CTsn5ueGU4oScNX1axu',
#        'id': '5p9CTsn5ueGU4oScNX1axu',
#        'name': 'August Burns Red',
#        'type': 'artist',
#        'uri': 'spotify:artist:5p9CTsn5ueGU4oScNX1axu'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1b0JaOIAQQjppqflWf8Q1N'},
#      'href': 'https://api.spotify.com/v1/albums/1b0JaOIAQQjppqflWf8Q1N',
#      'id': '1b0JaOIAQQjppqflWf8Q1N',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/147fee50671e2b3780d73360f74c02797a2083d8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/703ce9071c5932164d6cf4c71c6a2970dfe4c040',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/7b27b10b02f1ed9ae80a06c9a080783ed5d54feb',
#        'width': 64}],
#      'name': 'Thrill Seeker',
#      'release_date': '2005',
#      'release_date_precision': 'year',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1b0JaOIAQQjppqflWf8Q1N'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5p9CTsn5ueGU4oScNX1axu'},
#       'href': 'https://api.spotify.com/v1/artists/5p9CTsn5ueGU4oScNX1axu',
#       'id': '5p9CTsn5ueGU4oScNX1axu',
#       'name': 'August Burns Red',
#       'type': 'artist',
#       'uri': 'spotify:artist:5p9CTsn5ueGU4oScNX1axu'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 231386,
#     'explicit': False,
#     'external_ids': {'isrc': 'USTN10500247'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wbIpM37KUz9YFBG9GPdXv'},
#     'href': 'https://api.spotify.com/v1/tracks/0wbIpM37KUz9YFBG9GPdXv',
#     'id': '0wbIpM37KUz9YFBG9GPdXv',
#     'is_local': False,
#     'name': 'The Reflective Property',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/34b49830c044f463bcd62a898b673f17ef55543a?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0wbIpM37KUz9YFBG9GPdXv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0JTujDbHVqhWAGl06aaW78'},
#        'href': 'https://api.spotify.com/v1/artists/0JTujDbHVqhWAGl06aaW78',
#        'id': '0JTujDbHVqhWAGl06aaW78',
#        'name': 'Mariachi Vargas De Tecalitlan',
#        'type': 'artist',
#        'uri': 'spotify:artist:0JTujDbHVqhWAGl06aaW78'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7bfB8Xz308wXzASUXxQKIy'},
#      'href': 'https://api.spotify.com/v1/albums/7bfB8Xz308wXzASUXxQKIy',
#      'id': '7bfB8Xz308wXzASUXxQKIy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/065bcacb47b8d012c8b58d8e009b1a91836d8988',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/fdd051a19ea6a6100b62cdf68e90479ceffc2546',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/cc84f936553ec3e5afb151db755262e9bfeb4c32',
#        'width': 64}],
#      'name': 'Las Numero 1 Del Mariachi Vargas De Tecalitlan',
#      'release_date': '2005-10-18',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:7bfB8Xz308wXzASUXxQKIy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0JTujDbHVqhWAGl06aaW78'},
#       'href': 'https://api.spotify.com/v1/artists/0JTujDbHVqhWAGl06aaW78',
#       'id': '0JTujDbHVqhWAGl06aaW78',
#       'name': 'Mariachi Vargas De Tecalitlan',
#       'type': 'artist',
#       'uri': 'spotify:artist:0JTujDbHVqhWAGl06aaW78'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 217373,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF019100988'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/10JPsVewvvSmGMbnTrzy6b'},
#     'href': 'https://api.spotify.com/v1/tracks/10JPsVewvvSmGMbnTrzy6b',
#     'id': '10JPsVewvvSmGMbnTrzy6b',
#     'is_local': False,
#     'name': 'Fiesta en Jalisco',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cfcc4ac345a45ea0d46d75a7d0f32d23bd4e3ac0?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:10JPsVewvvSmGMbnTrzy6b'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#        'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#        'id': '0KDuKk6YdEu3hR56HtXmxt',
#        'name': 'Story Of The Year',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5IOgRGEVVKdFVuqL88I7sy'},
#      'href': 'https://api.spotify.com/v1/albums/5IOgRGEVVKdFVuqL88I7sy',
#      'id': '5IOgRGEVVKdFVuqL88I7sy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/405e9ebeb290552599ed3d7904ad630ba2990f7a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/61f7593cef5aff12ccd6a8ce4e72f72dd4fadc23',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ea0a53f9f0afe18646df97b1bd391bacc3de2aac',
#        'width': 64}],
#      'name': 'In The Wake Of Determination (PA Version)',
#      'release_date': '2005-10-10',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5IOgRGEVVKdFVuqL88I7sy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#       'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#       'id': '0KDuKk6YdEu3hR56HtXmxt',
#       'name': 'Story Of The Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 299862,
#     'explicit': True,
#     'external_ids': {'isrc': 'USMV20500220'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/12j0llNgqzDutJoT4sdVds'},
#     'href': 'https://api.spotify.com/v1/tracks/12j0llNgqzDutJoT4sdVds',
#     'id': '12j0llNgqzDutJoT4sdVds',
#     'is_local': False,
#     'name': '"Is This My Fate," He Asked Them',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bfc53dad68fd4a0a19f2a524bc89e3ed8b2d761f?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:12j0llNgqzDutJoT4sdVds'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0gxyHStUsqpMadRV0Di1Qt'},
#        'href': 'https://api.spotify.com/v1/artists/0gxyHStUsqpMadRV0Di1Qt',
#        'id': '0gxyHStUsqpMadRV0Di1Qt',
#        'name': 'Rick Astley',
#        'type': 'artist',
#        'uri': 'spotify:artist:0gxyHStUsqpMadRV0Di1Qt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3O84cNXlrQU6ewO6l5OuNp'},
#      'href': 'https://api.spotify.com/v1/albums/3O84cNXlrQU6ewO6l5OuNp',
#      'id': '3O84cNXlrQU6ewO6l5OuNp',
#      'images': [{'height': 638,
#        'url': 'https://i.scdn.co/image/959e68df4e11e8d2b39a1749f8808d183963914a',
#        'width': 640},
#       {'height': 299,
#        'url': 'https://i.scdn.co/image/c926df4638742caa73104d92483d755ce5e9b083',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/c7e118111ec7b32c87cbf052e50770beea39d16b',
#        'width': 64}],
#      'name': 'Portrait',
#      'release_date': '2005-10-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3O84cNXlrQU6ewO6l5OuNp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0gxyHStUsqpMadRV0Di1Qt'},
#       'href': 'https://api.spotify.com/v1/artists/0gxyHStUsqpMadRV0Di1Qt',
#       'id': '0gxyHStUsqpMadRV0Di1Qt',
#       'name': 'Rick Astley',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gxyHStUsqpMadRV0Di1Qt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194960,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL0500712'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/16o3RO4N802JXnZAEE7yXp'},
#     'href': 'https://api.spotify.com/v1/tracks/16o3RO4N802JXnZAEE7yXp',
#     'id': '16o3RO4N802JXnZAEE7yXp',
#     'is_local': False,
#     'name': "Can't Help Falling In Love (With You)",
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/313dbbaa6f20c838685b83899c0d7c88be00009a?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:16o3RO4N802JXnZAEE7yXp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZRkCThyw6syuSOAGT7lY1'},
#        'href': 'https://api.spotify.com/v1/artists/6ZRkCThyw6syuSOAGT7lY1',
#        'id': '6ZRkCThyw6syuSOAGT7lY1',
#        'name': 'Van Zant',
#        'type': 'artist',
#        'uri': 'spotify:artist:6ZRkCThyw6syuSOAGT7lY1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TlZtsAIXuZWNP8i7gKXsp'},
#      'href': 'https://api.spotify.com/v1/albums/1TlZtsAIXuZWNP8i7gKXsp',
#      'id': '1TlZtsAIXuZWNP8i7gKXsp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ff95f101904e85167e72056abdc9c42f7556eb26',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/0e25ab7899b3716a559ac7bbe94f78e186ee5057',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/57b98d6e2bc1cf76cd9adbb830842787c42c95d9',
#        'width': 64}],
#      'name': 'Get Right With The Man',
#      'release_date': '2005-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1TlZtsAIXuZWNP8i7gKXsp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZRkCThyw6syuSOAGT7lY1'},
#       'href': 'https://api.spotify.com/v1/artists/6ZRkCThyw6syuSOAGT7lY1',
#       'id': '6ZRkCThyw6syuSOAGT7lY1',
#       'name': 'Van Zant',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZRkCThyw6syuSOAGT7lY1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 233626,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10501318'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/17i2yZOOUHKACl2vNyiHeW'},
#     'href': 'https://api.spotify.com/v1/tracks/17i2yZOOUHKACl2vNyiHeW',
#     'id': '17i2yZOOUHKACl2vNyiHeW',
#     'is_local': False,
#     'name': 'Things I Miss The Most',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab8f27632fde65ebce2f234599153e2b6a25687b?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:17i2yZOOUHKACl2vNyiHeW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/762310PdDnwsDxAQxzQkfX'},
#        'href': 'https://api.spotify.com/v1/artists/762310PdDnwsDxAQxzQkfX',
#        'id': '762310PdDnwsDxAQxzQkfX',
#        'name': 'Depeche Mode',
#        'type': 'artist',
#        'uri': 'spotify:artist:762310PdDnwsDxAQxzQkfX'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0oHWHIlUObaSopO9wOhvfz'},
#      'href': 'https://api.spotify.com/v1/albums/0oHWHIlUObaSopO9wOhvfz',
#      'id': '0oHWHIlUObaSopO9wOhvfz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/5e78fdfb6403a3b72ce7dac427edb7fbdc361434',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ef2eaf945ba09e1aa4a0f1baf3711942818e2a7c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/6868b294614e5aab5869fac414d414697ab1a432',
#        'width': 64}],
#      'name': 'Playing The Angel',
#      'release_date': '2005-10-18',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0oHWHIlUObaSopO9wOhvfz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/762310PdDnwsDxAQxzQkfX'},
#       'href': 'https://api.spotify.com/v1/artists/762310PdDnwsDxAQxzQkfX',
#       'id': '762310PdDnwsDxAQxzQkfX',
#       'name': 'Depeche Mode',
#       'type': 'artist',
#       'uri': 'spotify:artist:762310PdDnwsDxAQxzQkfX'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 415040,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAJH0501457'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/17wy0YEQd6HLPqKz54UJc5'},
#     'href': 'https://api.spotify.com/v1/tracks/17wy0YEQd6HLPqKz54UJc5',
#     'id': '17wy0YEQd6HLPqKz54UJc5',
#     'is_local': False,
#     'name': 'The Darkest Star',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/59427ec4a900768c1237b861932c3e739c76b753?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:17wy0YEQd6HLPqKz54UJc5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rXLC3lGmx2JjclFJYZud4'},
#        'href': 'https://api.spotify.com/v1/artists/5rXLC3lGmx2JjclFJYZud4',
#        'id': '5rXLC3lGmx2JjclFJYZud4',
#        'name': 'Hidden In Plain View',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rXLC3lGmx2JjclFJYZud4'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4HGhXExvgwP0MhcvrFy4fv'},
#      'href': 'https://api.spotify.com/v1/albums/4HGhXExvgwP0MhcvrFy4fv',
#      'id': '4HGhXExvgwP0MhcvrFy4fv',
#      'images': [{'height': 629,
#        'url': 'https://i.scdn.co/image/08910ffa159dde1c3bb3d4a3133a3e326bc74504',
#        'width': 640},
#       {'height': 295,
#        'url': 'https://i.scdn.co/image/29ec0f4dcafba79b2aa020a5bc354863cdfd3092',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image/e1d683dc7809d8eb1470550bd9d6717846276c13',
#        'width': 64}],
#      'name': 'Life In Dreaming',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4HGhXExvgwP0MhcvrFy4fv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rXLC3lGmx2JjclFJYZud4'},
#       'href': 'https://api.spotify.com/v1/artists/5rXLC3lGmx2JjclFJYZud4',
#       'id': '5rXLC3lGmx2JjclFJYZud4',
#       'name': 'Hidden In Plain View',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rXLC3lGmx2JjclFJYZud4'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 288066,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAJE0401845'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/18tAOlaRdq04pqrjB8Lt8D'},
#     'href': 'https://api.spotify.com/v1/tracks/18tAOlaRdq04pqrjB8Lt8D',
#     'id': '18tAOlaRdq04pqrjB8Lt8D',
#     'is_local': False,
#     'name': 'Garden Statement',
#     'popularity': 23,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:18tAOlaRdq04pqrjB8Lt8D'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/57fbnHozNJMl16yNzt4agV'},
#        'href': 'https://api.spotify.com/v1/artists/57fbnHozNJMl16yNzt4agV',
#        'id': '57fbnHozNJMl16yNzt4agV',
#        'name': 'The Receiving End Of Sirens',
#        'type': 'artist',
#        'uri': 'spotify:artist:57fbnHozNJMl16yNzt4agV'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1M5DYiubn2ko8OpUs0lhEt'},
#      'href': 'https://api.spotify.com/v1/albums/1M5DYiubn2ko8OpUs0lhEt',
#      'id': '1M5DYiubn2ko8OpUs0lhEt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3eb58e9d643057495922005da5947f099a673900',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/2b6d8b1d6ccc866456ff46a3618bf080fec35ca1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/c127a9e80a3bc0278926efc29853259d67333e52',
#        'width': 64}],
#      'name': 'Between the Heart and the Synapse',
#      'release_date': '2005-04-26',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:1M5DYiubn2ko8OpUs0lhEt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/57fbnHozNJMl16yNzt4agV'},
#       'href': 'https://api.spotify.com/v1/artists/57fbnHozNJMl16yNzt4agV',
#       'id': '57fbnHozNJMl16yNzt4agV',
#       'name': 'The Receiving End Of Sirens',
#       'type': 'artist',
#       'uri': 'spotify:artist:57fbnHozNJMl16yNzt4agV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 330893,
#     'explicit': False,
#     'external_ids': {'isrc': 'US72W0510143'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1DRBvB3QNHnpkIdcMgMc2J'},
#     'href': 'https://api.spotify.com/v1/tracks/1DRBvB3QNHnpkIdcMgMc2J',
#     'id': '1DRBvB3QNHnpkIdcMgMc2J',
#     'is_local': False,
#     'name': 'The Rival Cycle',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/90d80e710b5ff1594286f0bd443269b8ae96cbc3?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1DRBvB3QNHnpkIdcMgMc2J'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/174ThXFgQg2VCq9r3m8ceb'},
#        'href': 'https://api.spotify.com/v1/artists/174ThXFgQg2VCq9r3m8ceb',
#        'id': '174ThXFgQg2VCq9r3m8ceb',
#        'name': 'Luiz Bonfá',
#        'type': 'artist',
#        'uri': 'spotify:artist:174ThXFgQg2VCq9r3m8ceb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/60xmVPU5u2ABpEqi2g8ZIn'},
#      'href': 'https://api.spotify.com/v1/albums/60xmVPU5u2ABpEqi2g8ZIn',
#      'id': '60xmVPU5u2ABpEqi2g8ZIn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/7134082f7bb235c704325fec8daf93593a5ab3cf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/67e009aaf22195bfd804fe1a0dd1523a6e4048b8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b9edffcaf2b4a8791ab8ef88e6f20a4c90a4df9a',
#        'width': 64}],
#      'name': 'Solo in Rio 1959',
#      'release_date': '2005-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:60xmVPU5u2ABpEqi2g8ZIn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/174ThXFgQg2VCq9r3m8ceb'},
#       'href': 'https://api.spotify.com/v1/artists/174ThXFgQg2VCq9r3m8ceb',
#       'id': '174ThXFgQg2VCq9r3m8ceb',
#       'name': 'Luiz Bonfá',
#       'type': 'artist',
#       'uri': 'spotify:artist:174ThXFgQg2VCq9r3m8ceb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 130173,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSF10548302'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1DThYRRQ0Hwtn1JeJNAqyK'},
#     'href': 'https://api.spotify.com/v1/tracks/1DThYRRQ0Hwtn1JeJNAqyK',
#     'id': '1DThYRRQ0Hwtn1JeJNAqyK',
#     'is_local': False,
#     'name': 'Night and Day',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/37dbc28a1d4ae3084946b807e415a455af6c2acd?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1DThYRRQ0Hwtn1JeJNAqyK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ixB75BQR3ADoWQkcHQJTs'},
#        'href': 'https://api.spotify.com/v1/artists/5ixB75BQR3ADoWQkcHQJTs',
#        'id': '5ixB75BQR3ADoWQkcHQJTs',
#        'name': 'Gene Autry',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ixB75BQR3ADoWQkcHQJTs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3P6M5MLTnlE2sngM0iMvV8'},
#      'href': 'https://api.spotify.com/v1/albums/3P6M5MLTnlE2sngM0iMvV8',
#      'id': '3P6M5MLTnlE2sngM0iMvV8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3c15289b69fc2670f0c9c357312ce3dcc33a3e28',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/9aa9cc38b2745fd10fa16634cbdf337b20a25798',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/49bdae3b9606b40001bc00981a663a64f1b60374',
#        'width': 64}],
#      'name': 'The Essential Gene Autry',
#      'release_date': '2005-01-11',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:3P6M5MLTnlE2sngM0iMvV8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ixB75BQR3ADoWQkcHQJTs'},
#       'href': 'https://api.spotify.com/v1/artists/5ixB75BQR3ADoWQkcHQJTs',
#       'id': '5ixB75BQR3ADoWQkcHQJTs',
#       'name': 'Gene Autry',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ixB75BQR3ADoWQkcHQJTs'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 158533,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10414363'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Hr94ZADw5cfltOCueNNPK'},
#     'href': 'https://api.spotify.com/v1/tracks/1Hr94ZADw5cfltOCueNNPK',
#     'id': '1Hr94ZADw5cfltOCueNNPK',
#     'is_local': False,
#     'name': 'Home On The Range',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a8a385d0cba59d21db084a6abde554079205329e?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:1Hr94ZADw5cfltOCueNNPK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FBDDo06NZR5B7qOzmMxq9'},
#        'href': 'https://api.spotify.com/v1/artists/2FBDDo06NZR5B7qOzmMxq9',
#        'id': '2FBDDo06NZR5B7qOzmMxq9',
#        'name': 'Charon',
#        'type': 'artist',
#        'uri': 'spotify:artist:2FBDDo06NZR5B7qOzmMxq9'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0o6M1hsbDu672f3muUCxw7'},
#      'href': 'https://api.spotify.com/v1/albums/0o6M1hsbDu672f3muUCxw7',
#      'id': '0o6M1hsbDu672f3muUCxw7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/1e9e7da8dd03e0bcd79bbf686735c98759cdf845',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/49fb4a5020ddb1ab2879139df5900f6d6e89e82c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/335f9314735bac75aeab84bcdffbfd41b0acbe65',
#        'width': 64}],
#      'name': 'Songs for the Sinners (Finnish version)',
#      'release_date': '2005',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0o6M1hsbDu672f3muUCxw7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FBDDo06NZR5B7qOzmMxq9'},
#       'href': 'https://api.spotify.com/v1/artists/2FBDDo06NZR5B7qOzmMxq9',
#       'id': '2FBDDo06NZR5B7qOzmMxq9',
#       'name': 'Charon',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FBDDo06NZR5B7qOzmMxq9'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 290426,
#     'explicit': False,
#     'external_ids': {'isrc': 'FISFS0500097'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1QtUT1YLzZ11t0pKImR8dF'},
#     'href': 'https://api.spotify.com/v1/tracks/1QtUT1YLzZ11t0pKImR8dF',
#     'id': '1QtUT1YLzZ11t0pKImR8dF',
#     'is_local': False,
# ...
#     'id': '47Bnav29zD2TSLeqWW4ZKe',
#     'is_local': False,
#     'name': 'God Bless Our Dead Marines',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f38f73f2ff5c309b3f15813d1af7d748a2de5140?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:47Bnav29zD2TSLeqWW4ZKe'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11mqrDSFRRz8g0Wb3syJj5'},
#        'href': 'https://api.spotify.com/v1/artists/11mqrDSFRRz8g0Wb3syJj5',
#        'id': '11mqrDSFRRz8g0Wb3syJj5',
#        'name': 'Panteon Rococo',
#        'type': 'artist',
#        'uri': 'spotify:artist:11mqrDSFRRz8g0Wb3syJj5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0HgimXrbh89mAHF3nLGsLP'},
#      'href': 'https://api.spotify.com/v1/albums/0HgimXrbh89mAHF3nLGsLP',
#      'id': '0HgimXrbh89mAHF3nLGsLP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3a5d02427625e817cbcbc48dbdee32234c1ede66',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/d5a46512384890308fdb76b405415b19f7f6225d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5fba21a3a1cfc764b6e1b675012b3adac4b7a584',
#        'width': 64}],
#      'name': 'Un Panteon Muy Vivo',
#      'release_date': '2005-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:0HgimXrbh89mAHF3nLGsLP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11mqrDSFRRz8g0Wb3syJj5'},
#       'href': 'https://api.spotify.com/v1/artists/11mqrDSFRRz8g0Wb3syJj5',
#       'id': '11mqrDSFRRz8g0Wb3syJj5',
#       'name': 'Panteon Rococo',
#       'type': 'artist',
#       'uri': 'spotify:artist:11mqrDSFRRz8g0Wb3syJj5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 387826,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF010500286'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/49J0QmYt43hbNp0G1294iC'},
#     'href': 'https://api.spotify.com/v1/tracks/49J0QmYt43hbNp0G1294iC',
#     'id': '49J0QmYt43hbNp0G1294iC',
#     'is_local': False,
#     'name': 'Centerfold Blues / La Rubia y el Demonio',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fb730741770a5c69570ff48125f62498b2d75639?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:49J0QmYt43hbNp0G1294iC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rVDi66o7gdeUq1OHUzM0W'},
#        'href': 'https://api.spotify.com/v1/artists/2rVDi66o7gdeUq1OHUzM0W',
#        'id': '2rVDi66o7gdeUq1OHUzM0W',
#        'name': 'The Protomen',
#        'type': 'artist',
#        'uri': 'spotify:artist:2rVDi66o7gdeUq1OHUzM0W'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3qHPyK7e96uprnWQWzVOnB'},
#      'href': 'https://api.spotify.com/v1/albums/3qHPyK7e96uprnWQWzVOnB',
#      'id': '3qHPyK7e96uprnWQWzVOnB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ebcf8b3ad06409118d35c8937ff3f6cb4dbfc540',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/95c38d6480503a2f9907de8b8b2f17d7b6371e61',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/16e29cfb9734ad83f65072632485db8a380fbb4c',
#        'width': 64}],
#      'name': 'The Protomen',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:3qHPyK7e96uprnWQWzVOnB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rVDi66o7gdeUq1OHUzM0W'},
#       'href': 'https://api.spotify.com/v1/artists/2rVDi66o7gdeUq1OHUzM0W',
#       'id': '2rVDi66o7gdeUq1OHUzM0W',
#       'name': 'The Protomen',
#       'type': 'artist',
#       'uri': 'spotify:artist:2rVDi66o7gdeUq1OHUzM0W'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243480,
#     'explicit': False,
#     'external_ids': {'isrc': 'ushm20676886'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4AMPduwQPjNsqpz7Mmwn5i'},
#     'href': 'https://api.spotify.com/v1/tracks/4AMPduwQPjNsqpz7Mmwn5i',
#     'id': '4AMPduwQPjNsqpz7Mmwn5i',
#     'is_local': False,
#     'name': 'EPILOGUE: Due Vendetta',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/be4a6d686e93b460a12cf7954d2908450d0d5996?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4AMPduwQPjNsqpz7Mmwn5i'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7fWgqc4HJi3pcHhK8hKg2p'},
#        'href': 'https://api.spotify.com/v1/artists/7fWgqc4HJi3pcHhK8hKg2p',
#        'id': '7fWgqc4HJi3pcHhK8hKg2p',
#        'name': 'Dope',
#        'type': 'artist',
#        'uri': 'spotify:artist:7fWgqc4HJi3pcHhK8hKg2p'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1PmZOixqTaRkJ6YHJq6gwa'},
#      'href': 'https://api.spotify.com/v1/albums/1PmZOixqTaRkJ6YHJq6gwa',
#      'id': '1PmZOixqTaRkJ6YHJq6gwa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c744aee5286e0a0e1efcf53dd399adcb52d311bb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/b4234930e29e1b740dc8fc3034127ef0297cbe06',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab96a3a1758faff30e0a8630e57fad62d59fd49d',
#        'width': 64}],
#      'name': 'American Apathy',
#      'release_date': '2005-07-26',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1PmZOixqTaRkJ6YHJq6gwa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7fWgqc4HJi3pcHhK8hKg2p'},
#       'href': 'https://api.spotify.com/v1/artists/7fWgqc4HJi3pcHhK8hKg2p',
#       'id': '7fWgqc4HJi3pcHhK8hKg2p',
#       'name': 'Dope',
#       'type': 'artist',
#       'uri': 'spotify:artist:7fWgqc4HJi3pcHhK8hKg2p'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196973,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAR50552038'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4AQ3UW7El4Hu3pJBeQ805r'},
#     'href': 'https://api.spotify.com/v1/tracks/4AQ3UW7El4Hu3pJBeQ805r',
#     'id': '4AQ3UW7El4Hu3pJBeQ805r',
#     'is_local': False,
#     'name': 'Burn',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/82e9829547012e50f5034e804c2e6209a3894aa7?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:4AQ3UW7El4Hu3pJBeQ805r'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mFX1QlezK1lNPKQJkhwWb'},
#        'href': 'https://api.spotify.com/v1/artists/1mFX1QlezK1lNPKQJkhwWb',
#        'id': '1mFX1QlezK1lNPKQJkhwWb',
#        'name': 'New Edition',
#        'type': 'artist',
#        'uri': 'spotify:artist:1mFX1QlezK1lNPKQJkhwWb'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LV',
#       'MC',
#       'MT',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7r7Vb7w9Fc3kUDNgIlPIxk'},
#      'href': 'https://api.spotify.com/v1/albums/7r7Vb7w9Fc3kUDNgIlPIxk',
#      'id': '7r7Vb7w9Fc3kUDNgIlPIxk',
#      'images': [{'height': 634,
#        'url': 'https://i.scdn.co/image/8b2e6c809a83c0452aa9871647b3cea38f13ad25',
#        'width': 640},
#       {'height': 297,
#        'url': 'https://i.scdn.co/image/bbe46338c6be98ce05cf2ade55a63d3eb0678db0',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image/4cb3edaf97595099b818cd32963ea1cbd01aabe5',
#        'width': 64}],
#      'name': 'Gold',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 34,
#      'type': 'album',
#      'uri': 'spotify:album:7r7Vb7w9Fc3kUDNgIlPIxk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2zFZiWQJFFshzojycnXoTL'},
#       'href': 'https://api.spotify.com/v1/artists/2zFZiWQJFFshzojycnXoTL',
#       'id': '2zFZiWQJFFshzojycnXoTL',
#       'name': 'Bell Biv DeVoe',
#       'type': 'artist',
#       'uri': 'spotify:artist:2zFZiWQJFFshzojycnXoTL'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 274200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC19031166'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4JvacMyrylsX8C281ZQ3m9'},
#     'href': 'https://api.spotify.com/v1/tracks/4JvacMyrylsX8C281ZQ3m9',
#     'id': '4JvacMyrylsX8C281ZQ3m9',
#     'is_local': False,
#     'name': 'B.B.D. (I Thought It Was Me)?',
#     'popularity': 29,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4JvacMyrylsX8C281ZQ3m9'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=year%3A2005&type=track&offset=10000&limit=50',
#   'offset': 9950,
#   'previous': 'https://api.spotify.com/v1/search?query=year%3A2005&type=track&offset=9900&limit=50',
#   'total': 1006318}}

# %%
track_results['tracks']['items'][1]['album']['images'][0]['url']
# Out:
# 'https://i.scdn.co/image/09488edb691315df75090584328e095efd9b2576'

# %%
print('number of elements in the track_id list:', len(track_id))
# Out:
# number of elements in the track_id list: 10000

# %%
import pandas as pd

df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity,
                         'url':spotify_href,'images':images,'date':release_date})
print(df_tracks.shape)
df_tracks.head()
# Out:
# (10000, 7)
#            artist_name                                track_name  \
# 0  Panic! At The Disco                I Write Sins Not Tragedies
# 1               Eminem  Lose Yourself - From "8 Mile" Soundtrack
# 2         Fall Out Boy                    Sugar, We're Goin Down
# 3           Kanye West                               Gold Digger
# 4      Plain White T's                         Hey There Delilah
#
#                  track_id  popularity  \
# 0  4bPQs0PHn4xbipzdPfn6du          76
# 1  5Z01UMMf7V1o0MzF86s6WJ          80
# 2  2TfSHkHiFO4gRztVIkggkE          78
# 3  1PS1QMdUqOal0ai3Gt7sDQ          78
# 4  4RCWB3V8V0dignt99LZ8vH          79
#
#                                                  url  \
# 0  https://open.spotify.com/track/4bPQs0PHn4xbipz...
# 1  https://open.spotify.com/track/5Z01UMMf7V1o0Mz...
# 2  https://open.spotify.com/track/2TfSHkHiFO4gRzt...
# 3  https://open.spotify.com/track/1PS1QMdUqOal0ai...
# 4  https://open.spotify.com/track/4RCWB3V8V0dignt...
#
#                                               images        date
# 0  https://i.scdn.co/image/76c86f33b0ffc852e4141e...  2005-09-27
# 1  https://i.scdn.co/image/77eb7c17cafe5503fc12e9...  2005-12-06
# 2  https://i.scdn.co/image/63a37f32006eab70bd58c8...  2005-01-01
# 3  https://i.scdn.co/image/92db1dda6ed503723c89c3...  2005-09-30
# 4  https://i.scdn.co/image/3a3e50577a99bfca93494b...  2005-01-01

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
# artist_name    10000 non-null object
# track_name     10000 non-null object
# track_id       10000 non-null object
# popularity     10000 non-null int64
# url            10000 non-null object
# images         10000 non-null object
# date           10000 non-null object
# dtypes: int64(1), object(6)
# memory usage: 547.0+ KB

# %%
 # group the entries by artist_name and track_name and check for duplicates

grouped = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
grouped[grouped > 1].count()
# Out:
# 376

# %%
df_tracks.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
# doing the same grouping as before to verify the solution
grouped_after_dropping = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %%
df_tracks[df_tracks.duplicated(subset=['artist_name','track_name'],keep=False)].count()
# Out:
# artist_name    0
# track_name     0
# track_id       0
# popularity     0
# url            0
# images         0
# date           0
# dtype: int64

# %%
df_tracks.shape
# Out:
# (9599, 7)

# %%
# again measuring the time
start = timeit.default_timer()

# empty list, batchsize and the counter for None results
rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(df_tracks['track_id']),batchsize):
    batch = df_tracks['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)
            
print('Number of tracks where no audio features were available:',None_counter)

stop = timeit.default_timer()
print ('Time to run this code (in seconds):',stop - start)
# Out:
# Number of tracks where no audio features were available: 0
# Time to run this code (in seconds): 31.137054060999986

# %% [markdown]
# ## 트랙의 다른 유용한 데이터 찾기

# %%
# 트랙의 장르 값 찾아보기
feature_results
# Out:
# [{'danceability': 0.352,
#   'energy': 0.319,
#   'key': 0,
#   'loudness': -17.635,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.882,
#   'instrumentalness': 0.879,
#   'liveness': 0.405,
#   'valence': 0.436,
#   'tempo': 176.439,
#   'type': 'audio_features',
#   'id': '4xbhOd2MLaqBylpk2Q4UF9',
#   'uri': 'spotify:track:4xbhOd2MLaqBylpk2Q4UF9',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xbhOd2MLaqBylpk2Q4UF9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xbhOd2MLaqBylpk2Q4UF9',
#   'duration_ms': 424200,
#   'time_signature': 3},
#  {'danceability': 0.853,
#   'energy': 0.726,
#   'key': 4,
#   'loudness': -5.538,
#   'mode': 0,
#   'speechiness': 0.0564,
#   'acousticness': 0.00431,
#   'instrumentalness': 0.591,
#   'liveness': 0.765,
#   'valence': 0.662,
#   'tempo': 120.506,
#   'type': 'audio_features',
#   'id': '57QCMbXNiEwurLPprfD3Gq',
#   'uri': 'spotify:track:57QCMbXNiEwurLPprfD3Gq',
#   'track_href': 'https://api.spotify.com/v1/tracks/57QCMbXNiEwurLPprfD3Gq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57QCMbXNiEwurLPprfD3Gq',
#   'duration_ms': 290600,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.721,
#   'key': 7,
#   'loudness': -6.208,
#   'mode': 1,
#   'speechiness': 0.0416,
#   'acousticness': 0.143,
#   'instrumentalness': 0,
#   'liveness': 0.335,
#   'valence': 0.77,
#   'tempo': 105.846,
#   'type': 'audio_features',
#   'id': '5EN9U0UAl43qyQsjBEdFC6',
#   'uri': 'spotify:track:5EN9U0UAl43qyQsjBEdFC6',
#   'track_href': 'https://api.spotify.com/v1/tracks/5EN9U0UAl43qyQsjBEdFC6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5EN9U0UAl43qyQsjBEdFC6',
#   'duration_ms': 238440,
#   'time_signature': 4},
#  {'danceability': 0.528,
#   'energy': 0.786,
#   'key': 6,
#   'loudness': -4.968,
#   'mode': 1,
#   'speechiness': 0.211,
#   'acousticness': 0.526,
#   'instrumentalness': 0,
#   'liveness': 0.157,
#   'valence': 0.658,
#   'tempo': 78.361,
#   'type': 'audio_features',
#   'id': '5FeKpctO9cDfQXEPNGpzhj',
#   'uri': 'spotify:track:5FeKpctO9cDfQXEPNGpzhj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FeKpctO9cDfQXEPNGpzhj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FeKpctO9cDfQXEPNGpzhj',
#   'duration_ms': 223507,
#   'time_signature': 4},
#  {'danceability': 0.875,
#   'energy': 0.799,
#   'key': 2,
#   'loudness': -5.531,
#   'mode': 1,
#   'speechiness': 0.0533,
#   'acousticness': 0.0433,
#   'instrumentalness': 0,
#   'liveness': 0.0764,
#   'valence': 0.792,
#   'tempo': 124.964,
#   'type': 'audio_features',
#   'id': '5IRpmH03HXibFqRfRRPlcb',
#   'uri': 'spotify:track:5IRpmH03HXibFqRfRRPlcb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IRpmH03HXibFqRfRRPlcb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IRpmH03HXibFqRfRRPlcb',
#   'duration_ms': 177147,
#   'time_signature': 4},
#  {'danceability': 0.797,
#   'energy': 0.687,
#   'key': 4,
#   'loudness': -9.195,
#   'mode': 0,
#   'speechiness': 0.0675,
#   'acousticness': 0.163,
#   'instrumentalness': 0.0355,
#   'liveness': 0.109,
#   'valence': 0.917,
#   'tempo': 168.0,
#   'type': 'audio_features',
#   'id': '5LDD8Wkcf8LDwtTfgxlIUr',
#   'uri': 'spotify:track:5LDD8Wkcf8LDwtTfgxlIUr',
#   'track_href': 'https://api.spotify.com/v1/tracks/5LDD8Wkcf8LDwtTfgxlIUr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LDD8Wkcf8LDwtTfgxlIUr',
#   'duration_ms': 249760,
#   'time_signature': 4},
#  {'danceability': 0.859,
#   'energy': 0.689,
#   'key': 7,
#   'loudness': -5.442,
#   'mode': 1,
#   'speechiness': 0.258,
#   'acousticness': 0.164,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.565,
#   'tempo': 92.936,
#   'type': 'audio_features',
#   'id': '5PovUdvytSkEhCD7pomwJB',
#   'uri': 'spotify:track:5PovUdvytSkEhCD7pomwJB',
#   'track_href': 'https://api.spotify.com/v1/tracks/5PovUdvytSkEhCD7pomwJB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PovUdvytSkEhCD7pomwJB',
#   'duration_ms': 269547,
#   'time_signature': 4},
#  {'danceability': 0.411,
#   'energy': 0.979,
#   'key': 6,
#   'loudness': -3.78,
#   'mode': 1,
#   'speechiness': 0.0947,
#   'acousticness': 1.34e-05,
#   'instrumentalness': 0.000252,
#   'liveness': 0.801,
#   'valence': 0.303,
#   'tempo': 109.964,
#   'type': 'audio_features',
#   'id': '5TISOiwexSROBtd0zf0tAp',
#   'uri': 'spotify:track:5TISOiwexSROBtd0zf0tAp',
#   'track_href': 'https://api.spotify.com/v1/tracks/5TISOiwexSROBtd0zf0tAp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5TISOiwexSROBtd0zf0tAp',
#   'duration_ms': 195400,
#   'time_signature': 4},
#  {'danceability': 0.383,
#   'energy': 0.949,
#   'key': 4,
#   'loudness': -7.48,
#   'mode': 1,
#   'speechiness': 0.0925,
#   'acousticness': 1.15e-05,
#   'instrumentalness': 0.0615,
#   'liveness': 0.213,
#   'valence': 0.172,
#   'tempo': 127.877,
#   'type': 'audio_features',
#   'id': '5mBFtvExoImDdTCu1OU0ks',
#   'uri': 'spotify:track:5mBFtvExoImDdTCu1OU0ks',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mBFtvExoImDdTCu1OU0ks',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mBFtvExoImDdTCu1OU0ks',
#   'duration_ms': 135467,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.716,
#   'key': 5,
#   'loudness': -5.04,
#   'mode': 1,
#   'speechiness': 0.0674,
#   'acousticness': 0.0826,
#   'instrumentalness': 0.0209,
#   'liveness': 0.285,
#   'valence': 0.563,
#   'tempo': 95.992,
#   'type': 'audio_features',
#   'id': '5zTg40C1vgVacG75BsP62Q',
#   'uri': 'spotify:track:5zTg40C1vgVacG75BsP62Q',
#   'track_href': 'https://api.spotify.com/v1/tracks/5zTg40C1vgVacG75BsP62Q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zTg40C1vgVacG75BsP62Q',
#   'duration_ms': 213760,
#   'time_signature': 4},
#  {'danceability': 0.732,
#   'energy': 0.402,
#   'key': 8,
#   'loudness': -13.69,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.669,
#   'instrumentalness': 0,
#   'liveness': 0.24,
#   'valence': 0.727,
#   'tempo': 102.795,
#   'type': 'audio_features',
#   'id': '626rUoXl2ochbgaugPH4Eh',
#   'uri': 'spotify:track:626rUoXl2ochbgaugPH4Eh',
#   'track_href': 'https://api.spotify.com/v1/tracks/626rUoXl2ochbgaugPH4Eh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/626rUoXl2ochbgaugPH4Eh',
#   'duration_ms': 122933,
#   'time_signature': 4},
#  {'danceability': 0.942,
#   'energy': 0.749,
#   'key': 9,
#   'loudness': -6.823,
#   'mode': 1,
#   'speechiness': 0.0949,
#   'acousticness': 0.0725,
#   'instrumentalness': 0.84,
#   'liveness': 0.0998,
#   'valence': 0.498,
#   'tempo': 126.509,
#   'type': 'audio_features',
#   'id': '65nT6PBpnn9z23IXEOmrig',
#   'uri': 'spotify:track:65nT6PBpnn9z23IXEOmrig',
#   'track_href': 'https://api.spotify.com/v1/tracks/65nT6PBpnn9z23IXEOmrig',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/65nT6PBpnn9z23IXEOmrig',
#   'duration_ms': 175682,
#   'time_signature': 4},
#  {'danceability': 0.429,
#   'energy': 0.972,
#   'key': 7,
#   'loudness': -3.329,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.751,
#   'instrumentalness': 0.808,
#   'liveness': 0.38,
#   'valence': 0.841,
#   'tempo': 91.239,
#   'type': 'audio_features',
#   'id': '6HDDb9qLwZ5dPNL2pxkqYv',
#   'uri': 'spotify:track:6HDDb9qLwZ5dPNL2pxkqYv',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HDDb9qLwZ5dPNL2pxkqYv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HDDb9qLwZ5dPNL2pxkqYv',
#   'duration_ms': 130400,
#   'time_signature': 4},
#  {'danceability': 0.762,
#   'energy': 0.663,
#   'key': 7,
#   'loudness': -5.596,
#   'mode': 1,
#   'speechiness': 0.174,
#   'acousticness': 0.11,
#   'instrumentalness': 0,
#   'liveness': 0.098,
#   'valence': 0.766,
#   'tempo': 87.017,
#   'type': 'audio_features',
#   'id': '6JZzDpa2TdBkB5yVG7amjQ',
#   'uri': 'spotify:track:6JZzDpa2TdBkB5yVG7amjQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JZzDpa2TdBkB5yVG7amjQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JZzDpa2TdBkB5yVG7amjQ',
#   'duration_ms': 267973,
#   'time_signature': 4},
#  {'danceability': 0.471,
#   'energy': 0.92,
#   'key': 7,
#   'loudness': -4.473,
#   'mode': 1,
#   'speechiness': 0.057,
#   'acousticness': 0.00387,
#   'instrumentalness': 2.12e-05,
#   'liveness': 0.044,
#   'valence': 0.784,
#   'tempo': 102.325,
#   'type': 'audio_features',
#   'id': '6KPSJEnQQnOMylCq2QOB0T',
#   'uri': 'spotify:track:6KPSJEnQQnOMylCq2QOB0T',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KPSJEnQQnOMylCq2QOB0T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KPSJEnQQnOMylCq2QOB0T',
#   'duration_ms': 242253,
#   'time_signature': 4},
#  {'danceability': 0.406,
#   'energy': 0.813,
#   'key': 4,
#   'loudness': -10.632,
#   'mode': 0,
#   'speechiness': 0.0467,
#   'acousticness': 0.0687,
#   'instrumentalness': 0.186,
#   'liveness': 0.175,
#   'valence': 0.816,
#   'tempo': 130.457,
#   'type': 'audio_features',
#   'id': '6Sgmt1jdLbD3DrEbcIdhBD',
#   'uri': 'spotify:track:6Sgmt1jdLbD3DrEbcIdhBD',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sgmt1jdLbD3DrEbcIdhBD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sgmt1jdLbD3DrEbcIdhBD',
#   'duration_ms': 209908,
#   'time_signature': 4},
#  {'danceability': 0.533,
#   'energy': 0.997,
#   'key': 8,
#   'loudness': -4.323,
#   'mode': 1,
#   'speechiness': 0.225,
#   'acousticness': 0.000208,
#   'instrumentalness': 1.42e-05,
#   'liveness': 0.11,
#   'valence': 0.0558,
#   'tempo': 115.103,
#   'type': 'audio_features',
#   'id': '6SwSpU5R1r3gNC6vFsizz5',
#   'uri': 'spotify:track:6SwSpU5R1r3gNC6vFsizz5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SwSpU5R1r3gNC6vFsizz5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SwSpU5R1r3gNC6vFsizz5',
#   'duration_ms': 285013,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.807,
#   'key': 11,
#   'loudness': -5.159,
#   'mode': 0,
#   'speechiness': 0.058,
#   'acousticness': 0.348,
#   'instrumentalness': 1.68e-05,
#   'liveness': 0.0406,
#   'valence': 0.932,
#   'tempo': 101.903,
#   'type': 'audio_features',
#   'id': '6TWSA3Tdg1c0w3q2OWfyRh',
#   'uri': 'spotify:track:6TWSA3Tdg1c0w3q2OWfyRh',
#   'track_href': 'https://api.spotify.com/v1/tracks/6TWSA3Tdg1c0w3q2OWfyRh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6TWSA3Tdg1c0w3q2OWfyRh',
#   'duration_ms': 220867,
#   'time_signature': 4},
#  {'danceability': 0.496,
#   'energy': 0.939,
#   'key': 9,
#   'loudness': -7.184,
#   'mode': 0,
#   'speechiness': 0.125,
#   'acousticness': 0.00229,
#   'instrumentalness': 0.844,
#   'liveness': 0.199,
#   'valence': 0.262,
#   'tempo': 109.153,
#   'type': 'audio_features',
#   'id': '6YPeAuIL4TQKNgfwDPEAOD',
#   'uri': 'spotify:track:6YPeAuIL4TQKNgfwDPEAOD',
#   'track_href': 'https://api.spotify.com/v1/tracks/6YPeAuIL4TQKNgfwDPEAOD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YPeAuIL4TQKNgfwDPEAOD',
#   'duration_ms': 208120,
#   'time_signature': 4},
#  {'danceability': 0.301,
#   'energy': 0.0917,
#   'key': 11,
#   'loudness': -13.853,
#   'mode': 1,
#   'speechiness': 0.045,
#   'acousticness': 0.95,
#   'instrumentalness': 0,
#   'liveness': 0.144,
#   'valence': 0.542,
#   'tempo': 79.915,
#   'type': 'audio_features',
#   'id': '6lgHt8QrnuJnplbRfBcAY6',
#   'uri': 'spotify:track:6lgHt8QrnuJnplbRfBcAY6',
#   'track_href': 'https://api.spotify.com/v1/tracks/6lgHt8QrnuJnplbRfBcAY6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6lgHt8QrnuJnplbRfBcAY6',
#   'duration_ms': 186880,
#   'time_signature': 1},
#  {'danceability': 0.288,
#   'energy': 0.181,
#   'key': 4,
#   'loudness': -13.974,
#   'mode': 0,
#   'speechiness': 0.0498,
#   'acousticness': 0.711,
#   'instrumentalness': 0.00478,
#   'liveness': 0.287,
#   'valence': 0.0737,
#   'tempo': 99.265,
#   'type': 'audio_features',
#   'id': '6q9FT9sm83MhkBRt1GDnXd',
#   'uri': 'spotify:track:6q9FT9sm83MhkBRt1GDnXd',
#   'track_href': 'https://api.spotify.com/v1/tracks/6q9FT9sm83MhkBRt1GDnXd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6q9FT9sm83MhkBRt1GDnXd',
#   'duration_ms': 231600,
#   'time_signature': 4},
#  {'danceability': 0.399,
#   'energy': 0.756,
#   'key': 7,
#   'loudness': -6.343,
#   'mode': 1,
#   'speechiness': 0.036,
#   'acousticness': 0.0235,
#   'instrumentalness': 0.25,
#   'liveness': 0.837,
#   'valence': 0.481,
#   'tempo': 100.726,
#   'type': 'audio_features',
#   'id': '6usY7GwNGocGUOMJ49IExN',
#   'uri': 'spotify:track:6usY7GwNGocGUOMJ49IExN',
#   'track_href': 'https://api.spotify.com/v1/tracks/6usY7GwNGocGUOMJ49IExN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6usY7GwNGocGUOMJ49IExN',
#   'duration_ms': 997227,
#   'time_signature': 4},
#  {'danceability': 0.789,
#   'energy': 0.592,
#   'key': 7,
#   'loudness': -7.063,
#   'mode': 0,
#   'speechiness': 0.0501,
#   'acousticness': 0.0808,
#   'instrumentalness': 0.00079,
#   'liveness': 0.084,
#   'valence': 0.946,
#   'tempo': 96.969,
#   'type': 'audio_features',
#   'id': '6wdyJnmcSeBXUyR6H5gGKd',
#   'uri': 'spotify:track:6wdyJnmcSeBXUyR6H5gGKd',
#   'track_href': 'https://api.spotify.com/v1/tracks/6wdyJnmcSeBXUyR6H5gGKd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wdyJnmcSeBXUyR6H5gGKd',
#   'duration_ms': 318600,
#   'time_signature': 4},
#  {'danceability': 0.357,
#   'energy': 0.657,
#   'key': 7,
#   'loudness': -7.461,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.265,
#   'instrumentalness': 0.013,
#   'liveness': 0.163,
#   'valence': 0.225,
#   'tempo': 130.163,
#   'type': 'audio_features',
#   'id': '74k56xjvucElX9S5lY2O6t',
#   'uri': 'spotify:track:74k56xjvucElX9S5lY2O6t',
#   'track_href': 'https://api.spotify.com/v1/tracks/74k56xjvucElX9S5lY2O6t',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74k56xjvucElX9S5lY2O6t',
#   'duration_ms': 255373,
#   'time_signature': 4},
#  {'danceability': 0.582,
#   'energy': 0.838,
#   'key': 2,
#   'loudness': -4.489,
#   'mode': 1,
#   'speechiness': 0.03,
#   'acousticness': 0.0144,
#   'instrumentalness': 5.01e-06,
#   'liveness': 0.112,
#   'valence': 0.361,
#   'tempo': 104.987,
#   'type': 'audio_features',
#   'id': '7BIH3fdrShidS21RkGOAiQ',
#   'uri': 'spotify:track:7BIH3fdrShidS21RkGOAiQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BIH3fdrShidS21RkGOAiQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BIH3fdrShidS21RkGOAiQ',
#   'duration_ms': 216267,
#   'time_signature': 4},
#  {'danceability': 0.257,
#   'energy': 0.134,
#   'key': 8,
#   'loudness': -13.392,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.954,
#   'instrumentalness': 3.89e-05,
#   'liveness': 0.374,
#   'valence': 0.32,
#   'tempo': 83.856,
#   'type': 'audio_features',
#   'id': '7DFAgez4c92x6EKLfCUqoV',
#   'uri': 'spotify:track:7DFAgez4c92x6EKLfCUqoV',
#   'track_href': 'https://api.spotify.com/v1/tracks/7DFAgez4c92x6EKLfCUqoV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DFAgez4c92x6EKLfCUqoV',
#   'duration_ms': 152760,
#   'time_signature': 4},
#  {'danceability': 0.452,
#   'energy': 0.982,
#   'key': 2,
#   'loudness': -2.355,
#   'mode': 0,
#   'speechiness': 0.118,
#   'acousticness': 0.00143,
#   'instrumentalness': 0.0105,
#   'liveness': 0.0606,
#   'valence': 0.581,
#   'tempo': 154.99,
#   'type': 'audio_features',
#   'id': '7EEN3z8uwH1XA4TKAnVUyH',
#   'uri': 'spotify:track:7EEN3z8uwH1XA4TKAnVUyH',
#   'track_href': 'https://api.spotify.com/v1/tracks/7EEN3z8uwH1XA4TKAnVUyH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7EEN3z8uwH1XA4TKAnVUyH',
#   'duration_ms': 196293,
#   'time_signature': 4},
#  {'danceability': 0.452,
#   'energy': 0.945,
#   'key': 4,
#   'loudness': -4.317,
#   'mode': 1,
#   'speechiness': 0.162,
#   'acousticness': 0.0959,
#   'instrumentalness': 0,
#   'liveness': 0.304,
#   'valence': 0.945,
#   'tempo': 203.942,
#   'type': 'audio_features',
#   'id': '7EuQJsIpdIKrDYNfLtEyHL',
#   'uri': 'spotify:track:7EuQJsIpdIKrDYNfLtEyHL',
#   'track_href': 'https://api.spotify.com/v1/tracks/7EuQJsIpdIKrDYNfLtEyHL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7EuQJsIpdIKrDYNfLtEyHL',
#   'duration_ms': 142587,
#   'time_signature': 4},
#  {'danceability': 0.717,
#   'energy': 0.874,
#   'key': 9,
#   'loudness': -5.941,
#   'mode': 0,
#   'speechiness': 0.0537,
#   'acousticness': 0.384,
#   'instrumentalness': 8.81e-05,
#   'liveness': 0.0764,
#   'valence': 0.848,
#   'tempo': 99.02,
#   'type': 'audio_features',
#   'id': '7h6Nor6KP22FF6JPd2m9n1',
#   'uri': 'spotify:track:7h6Nor6KP22FF6JPd2m9n1',
#   'track_href': 'https://api.spotify.com/v1/tracks/7h6Nor6KP22FF6JPd2m9n1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7h6Nor6KP22FF6JPd2m9n1',
#   'duration_ms': 299547,
#   'time_signature': 4},
#  {'danceability': 0.664,
#   'energy': 0.921,
#   'key': 9,
#   'loudness': -3.803,
#   'mode': 0,
#   'speechiness': 0.104,
#   'acousticness': 0.0251,
#   'instrumentalness': 0,
#   'liveness': 0.175,
#   'valence': 0.766,
#   'tempo': 158.381,
#   'type': 'audio_features',
#   'id': '7jcxm0Ooi09u1LySzkBqm0',
#   'uri': 'spotify:track:7jcxm0Ooi09u1LySzkBqm0',
#   'track_href': 'https://api.spotify.com/v1/tracks/7jcxm0Ooi09u1LySzkBqm0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7jcxm0Ooi09u1LySzkBqm0',
#   'duration_ms': 241667,
#   'time_signature': 4},
#  {'danceability': 0.852,
#   'energy': 0.758,
#   'key': 11,
#   'loudness': -6.525,
#   'mode': 0,
#   'speechiness': 0.111,
#   'acousticness': 0.249,
#   'instrumentalness': 3.26e-05,
#   'liveness': 0.115,
#   'valence': 0.896,
#   'tempo': 130.027,
#   'type': 'audio_features',
#   'id': '7ortLJa2sNklfcE29QRBVP',
#   'uri': 'spotify:track:7ortLJa2sNklfcE29QRBVP',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ortLJa2sNklfcE29QRBVP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ortLJa2sNklfcE29QRBVP',
#   'duration_ms': 167640,
#   'time_signature': 4},
#  {'danceability': 0.134,
#   'energy': 0.199,
#   'key': 1,
#   'loudness': -16.249,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.964,
#   'instrumentalness': 0.989,
#   'liveness': 0.139,
#   'valence': 0.0362,
#   'tempo': 100.638,
#   'type': 'audio_features',
#   'id': '7x5HR4Tg0YBHuNDtgvfIWO',
#   'uri': 'spotify:track:7x5HR4Tg0YBHuNDtgvfIWO',
#   'track_href': 'https://api.spotify.com/v1/tracks/7x5HR4Tg0YBHuNDtgvfIWO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7x5HR4Tg0YBHuNDtgvfIWO',
#   'duration_ms': 143705,
#   'time_signature': 3},
#  {'danceability': 0.552,
#   'energy': 0.655,
#   'key': 11,
#   'loudness': -9.797,
#   'mode': 0,
#   'speechiness': 0.0613,
#   'acousticness': 0.0035,
#   'instrumentalness': 0.535,
#   'liveness': 0.117,
#   'valence': 0.626,
#   'tempo': 106.367,
#   'type': 'audio_features',
#   'id': '7zlRbNNKcBxZCqbSgT0GLy',
#   'uri': 'spotify:track:7zlRbNNKcBxZCqbSgT0GLy',
#   'track_href': 'https://api.spotify.com/v1/tracks/7zlRbNNKcBxZCqbSgT0GLy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7zlRbNNKcBxZCqbSgT0GLy',
#   'duration_ms': 177467,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.455,
#   'key': 5,
#   'loudness': -10.071,
#   'mode': 1,
#   'speechiness': 0.0283,
#   'acousticness': 0.669,
#   'instrumentalness': 0.000335,
#   'liveness': 0.13,
#   'valence': 0.861,
#   'tempo': 77.875,
#   'type': 'audio_features',
#   'id': '7zwF7Ucz6UpIDOH9CTExcE',
#   'uri': 'spotify:track:7zwF7Ucz6UpIDOH9CTExcE',
#   'track_href': 'https://api.spotify.com/v1/tracks/7zwF7Ucz6UpIDOH9CTExcE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7zwF7Ucz6UpIDOH9CTExcE',
#   'duration_ms': 168613,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.96,
#   'key': 5,
#   'loudness': -3.077,
#   'mode': 1,
#   'speechiness': 0.0923,
#   'acousticness': 0.144,
#   'instrumentalness': 0,
#   'liveness': 0.0488,
#   'valence': 0.871,
#   'tempo': 114.051,
#   'type': 'audio_features',
#   'id': '00nnYw5Sj0DOsKpjlKcISa',
#   'uri': 'spotify:track:00nnYw5Sj0DOsKpjlKcISa',
#   'track_href': 'https://api.spotify.com/v1/tracks/00nnYw5Sj0DOsKpjlKcISa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00nnYw5Sj0DOsKpjlKcISa',
#   'duration_ms': 229867,
#   'time_signature': 4},
#  {'danceability': 0.448,
#   'energy': 0.279,
#   'key': 2,
#   'loudness': -12.487,
#   'mode': 1,
#   'speechiness': 0.0262,
#   'acousticness': 0.775,
#   'instrumentalness': 0,
#   'liveness': 0.366,
#   'valence': 0.368,
#   'tempo': 92.845,
#   'type': 'audio_features',
#   'id': '04qYsVT7PsPRQLufaEdgHu',
#   'uri': 'spotify:track:04qYsVT7PsPRQLufaEdgHu',
#   'track_href': 'https://api.spotify.com/v1/tracks/04qYsVT7PsPRQLufaEdgHu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04qYsVT7PsPRQLufaEdgHu',
#   'duration_ms': 157333,
#   'time_signature': 3},
#  {'danceability': 0.726,
#   'energy': 0.486,
#   'key': 10,
#   'loudness': -7.917,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.833,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.395,
#   'tempo': 130.024,
#   'type': 'audio_features',
#   'id': '074shHX1vP0FVPNuLeSTss',
#   'uri': 'spotify:track:074shHX1vP0FVPNuLeSTss',
#   'track_href': 'https://api.spotify.com/v1/tracks/074shHX1vP0FVPNuLeSTss',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/074shHX1vP0FVPNuLeSTss',
#   'duration_ms': 213280,
#   'time_signature': 4},
#  {'danceability': 0.41,
#   'energy': 0.867,
#   'key': 3,
#   'loudness': -7.01,
#   'mode': 1,
#   'speechiness': 0.0797,
#   'acousticness': 0.0102,
#   'instrumentalness': 7.56e-06,
#   'liveness': 0.67,
#   'valence': 0.31,
#   'tempo': 149.966,
#   'type': 'audio_features',
#   'id': '08b5aZvxYtd23VxOHiQOpO',
#   'uri': 'spotify:track:08b5aZvxYtd23VxOHiQOpO',
#   'track_href': 'https://api.spotify.com/v1/tracks/08b5aZvxYtd23VxOHiQOpO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08b5aZvxYtd23VxOHiQOpO',
#   'duration_ms': 321293,
#   'time_signature': 4},
#  {'danceability': 0.427,
#   'energy': 0.377,
#   'key': 0,
#   'loudness': -12.516,
#   'mode': 0,
#   'speechiness': 0.038,
#   'acousticness': 0.293,
#   'instrumentalness': 0.000203,
#   'liveness': 0.239,
#   'valence': 0.404,
#   'tempo': 145.068,
#   'type': 'audio_features',
#   'id': '09PAOMUiAjZho9HVkd5umo',
#   'uri': 'spotify:track:09PAOMUiAjZho9HVkd5umo',
#   'track_href': 'https://api.spotify.com/v1/tracks/09PAOMUiAjZho9HVkd5umo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09PAOMUiAjZho9HVkd5umo',
#   'duration_ms': 295667,
#   'time_signature': 3},
#  {'danceability': 0.916,
#   'energy': 0.512,
#   'key': 1,
#   'loudness': -13.517,
#   'mode': 1,
#   'speechiness': 0.225,
#   'acousticness': 0.102,
#   'instrumentalness': 1.35e-05,
#   'liveness': 0.106,
#   'valence': 0.789,
#   'tempo': 96.001,
#   'type': 'audio_features',
#   'id': '0APqJzDh89lQMuMbfTkdxb',
#   'uri': 'spotify:track:0APqJzDh89lQMuMbfTkdxb',
#   'track_href': 'https://api.spotify.com/v1/tracks/0APqJzDh89lQMuMbfTkdxb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0APqJzDh89lQMuMbfTkdxb',
#   'duration_ms': 221973,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.753,
#   'key': 6,
#   'loudness': -7.185,
#   'mode': 0,
#   'speechiness': 0.0309,
#   'acousticness': 0.312,
#   'instrumentalness': 0.799,
#   'liveness': 0.091,
#   'valence': 0.337,
#   'tempo': 105.013,
#   'type': 'audio_features',
#   'id': '0AY8j7fUTfNgvRIMRyJoKe',
#   'uri': 'spotify:track:0AY8j7fUTfNgvRIMRyJoKe',
#   'track_href': 'https://api.spotify.com/v1/tracks/0AY8j7fUTfNgvRIMRyJoKe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0AY8j7fUTfNgvRIMRyJoKe',
#   'duration_ms': 259880,
#   'time_signature': 4},
#  {'danceability': 0.544,
#   'energy': 0.431,
#   'key': 0,
#   'loudness': -10.985,
#   'mode': 1,
#   'speechiness': 0.0293,
#   'acousticness': 0.43,
#   'instrumentalness': 0.00327,
#   'liveness': 0.114,
#   'valence': 0.408,
#   'tempo': 124.628,
#   'type': 'audio_features',
#   'id': '0BaGZ0Fv3Nk9xFlOaaNXRf',
#   'uri': 'spotify:track:0BaGZ0Fv3Nk9xFlOaaNXRf',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BaGZ0Fv3Nk9xFlOaaNXRf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BaGZ0Fv3Nk9xFlOaaNXRf',
#   'duration_ms': 211453,
#   'time_signature': 3},
#  {'danceability': 0.497,
#   'energy': 0.14,
#   'key': 4,
#   'loudness': -17.744,
#   'mode': 0,
#   'speechiness': 0.0556,
#   'acousticness': 0.529,
#   'instrumentalness': 0.877,
#   'liveness': 0.119,
#   'valence': 0.276,
#   'tempo': 151.17,
#   'type': 'audio_features',
#   'id': '0K2ZPWywoj9X5whlqA4Tmp',
#   'uri': 'spotify:track:0K2ZPWywoj9X5whlqA4Tmp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0K2ZPWywoj9X5whlqA4Tmp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0K2ZPWywoj9X5whlqA4Tmp',
#   'duration_ms': 185293,
#   'time_signature': 3},
#  {'danceability': 0.519,
#   'energy': 0.666,
#   'key': 9,
#   'loudness': -5.723,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.317,
#   'instrumentalness': 5.61e-05,
#   'liveness': 0.0704,
#   'valence': 0.42,
#   'tempo': 174.04,
#   'type': 'audio_features',
#   'id': '0P9Kt1i9pFr4e33fX8JyYh',
#   'uri': 'spotify:track:0P9Kt1i9pFr4e33fX8JyYh',
#   'track_href': 'https://api.spotify.com/v1/tracks/0P9Kt1i9pFr4e33fX8JyYh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0P9Kt1i9pFr4e33fX8JyYh',
#   'duration_ms': 209560,
#   'time_signature': 4},
#  {'danceability': 0.686,
#   'energy': 0.817,
#   'key': 9,
#   'loudness': -5.212,
#   'mode': 1,
#   'speechiness': 0.0342,
#   'acousticness': 0.46,
#   'instrumentalness': 1.85e-06,
#   'liveness': 0.196,
#   'valence': 0.963,
#   'tempo': 92.059,
#   'type': 'audio_features',
#   'id': '0RjQIQbBtSJqBOBjvh8OiY',
#   'uri': 'spotify:track:0RjQIQbBtSJqBOBjvh8OiY',
#   'track_href': 'https://api.spotify.com/v1/tracks/0RjQIQbBtSJqBOBjvh8OiY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0RjQIQbBtSJqBOBjvh8OiY',
#   'duration_ms': 149987,
#   'time_signature': 4},
#  {'danceability': 0.624,
#   'energy': 0.738,
#   'key': 10,
#   'loudness': -8.275,
#   'mode': 0,
#   'speechiness': 0.0735,
#   'acousticness': 0.53,
#   'instrumentalness': 0,
#   'liveness': 0.145,
#   'valence': 0.971,
#   'tempo': 146.916,
#   'type': 'audio_features',
#   'id': '0TiYdUDkf0d1Q04gGWq1Q1',
#   'uri': 'spotify:track:0TiYdUDkf0d1Q04gGWq1Q1',
#   'track_href': 'https://api.spotify.com/v1/tracks/0TiYdUDkf0d1Q04gGWq1Q1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0TiYdUDkf0d1Q04gGWq1Q1',
#   'duration_ms': 147564,
#   'time_signature': 4},
#  {'danceability': 0.512,
#   'energy': 0.477,
#   'key': 1,
#   'loudness': -8.039,
#   'mode': 0,
#   'speechiness': 0.0267,
#   'acousticness': 0.337,
#   'instrumentalness': 0,
#   'liveness': 0.0615,
#   'valence': 0.587,
#   'tempo': 179.177,
#   'type': 'audio_features',
#   'id': '0UjIAXcw2LbwjAV7WpNJdf',
#   'uri': 'spotify:track:0UjIAXcw2LbwjAV7WpNJdf',
#   'track_href': 'https://api.spotify.com/v1/tracks/0UjIAXcw2LbwjAV7WpNJdf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UjIAXcw2LbwjAV7WpNJdf',
#   'duration_ms': 218960,
#   'time_signature': 3},
#  {'danceability': 0.92,
#   'energy': 0.384,
#   'key': 11,
#   'loudness': -8.174,
#   'mode': 1,
#   'speechiness': 0.29,
#   'acousticness': 0.0623,
#   'instrumentalness': 0,
#   'liveness': 0.166,
#   'valence': 0.518,
#   'tempo': 91.052,
#   'type': 'audio_features',
#   'id': '0VM7hOqcw88iW0toXb25eU',
#   'uri': 'spotify:track:0VM7hOqcw88iW0toXb25eU',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VM7hOqcw88iW0toXb25eU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VM7hOqcw88iW0toXb25eU',
#   'duration_ms': 229693,
#   'time_signature': 4},
#  {'danceability': 0.558,
#   'energy': 0.524,
#   'key': 9,
#   'loudness': -8.556,
#   'mode': 0,
#   'speechiness': 0.0959,
#   'acousticness': 0.324,
#   'instrumentalness': 0,
#   'liveness': 0.627,
#   'valence': 0.546,
#   'tempo': 131.489,
#   'type': 'audio_features',
#   'id': '0cGpkGmSq6LcPeCPjiOmrr',
#   'uri': 'spotify:track:0cGpkGmSq6LcPeCPjiOmrr',
#   'track_href': 'https://api.spotify.com/v1/tracks/0cGpkGmSq6LcPeCPjiOmrr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cGpkGmSq6LcPeCPjiOmrr',
#   'duration_ms': 237653,
#   'time_signature': 4},
#  {'danceability': 0.406,
#   'energy': 0.445,
#   'key': 7,
#   'loudness': -10.731,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.0628,
#   'instrumentalness': 0.0124,
#   'liveness': 0.976,
#   'valence': 0.19,
#   'tempo': 104.685,
#   'type': 'audio_features',
#   'id': '0dl4Yb29wj8455kuKSSboL',
#   'uri': 'spotify:track:0dl4Yb29wj8455kuKSSboL',
#   'track_href': 'https://api.spotify.com/v1/tracks/0dl4Yb29wj8455kuKSSboL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0dl4Yb29wj8455kuKSSboL',
#   'duration_ms': 314787,
#   'time_signature': 4},
#  {'danceability': 0.571,
#   'energy': 0.591,
#   'key': 6,
#   'loudness': -17.747,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.796,
#   'instrumentalness': 0.719,
#   'liveness': 0.127,
#   'valence': 0.963,
#   'tempo': 138.698,
#   'type': 'audio_features',
#   'id': '0f1Mgnl24tDeGshwKScQKn',
#   'uri': 'spotify:track:0f1Mgnl24tDeGshwKScQKn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0f1Mgnl24tDeGshwKScQKn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0f1Mgnl24tDeGshwKScQKn',
#   'duration_ms': 260347,
#   'time_signature': 3},
#  {'danceability': 0.543,
#   'energy': 0.281,
#   'key': 9,
#   'loudness': -10.421,
#   'mode': 1,
#   'speechiness': 0.0461,
#   'acousticness': 0.61,
#   'instrumentalness': 0,
#   'liveness': 0.0642,
#   'valence': 0.556,
#   'tempo': 130.175,
#   'type': 'audio_features',
#   'id': '0qPGsdMGR7pKpxTyDCCXmL',
#   'uri': 'spotify:track:0qPGsdMGR7pKpxTyDCCXmL',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qPGsdMGR7pKpxTyDCCXmL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qPGsdMGR7pKpxTyDCCXmL',
#   'duration_ms': 212381,
#   'time_signature': 5},
#  {'danceability': 0.605,
#   'energy': 0.455,
#   'key': 5,
#   'loudness': -10.571,
#   'mode': 1,
#   'speechiness': 0.0284,
#   'acousticness': 0.497,
#   'instrumentalness': 0.00533,
#   'liveness': 0.141,
#   'valence': 0.422,
#   'tempo': 87.469,
#   'type': 'audio_features',
#   'id': '0r7CZrmB1vvPHIoKN0E6iA',
#   'uri': 'spotify:track:0r7CZrmB1vvPHIoKN0E6iA',
#   'track_href': 'https://api.spotify.com/v1/tracks/0r7CZrmB1vvPHIoKN0E6iA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0r7CZrmB1vvPHIoKN0E6iA',
#   'duration_ms': 360000,
#   'time_signature': 4},
#  {'danceability': 0.292,
#   'energy': 0.928,
#   'key': 1,
#   'loudness': -4.627,
#   'mode': 1,
#   'speechiness': 0.088,
#   'acousticness': 5.05e-06,
#   'instrumentalness': 0.486,
#   'liveness': 0.586,
#   'valence': 0.431,
#   'tempo': 92.886,
#   'type': 'audio_features',
#   'id': '0wbIpM37KUz9YFBG9GPdXv',
#   'uri': 'spotify:track:0wbIpM37KUz9YFBG9GPdXv',
#   'track_href': 'https://api.spotify.com/v1/tracks/0wbIpM37KUz9YFBG9GPdXv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wbIpM37KUz9YFBG9GPdXv',
#   'duration_ms': 231387,
#   'time_signature': 4},
#  {'danceability': 0.457,
#   'energy': 0.502,
#   'key': 2,
#   'loudness': -7.463,
#   'mode': 1,
#   'speechiness': 0.0372,
#   'acousticness': 0.742,
#   'instrumentalness': 4.18e-05,
#   'liveness': 0.559,
#   'valence': 0.694,
#   'tempo': 135.131,
#   'type': 'audio_features',
#   'id': '10JPsVewvvSmGMbnTrzy6b',
#   'uri': 'spotify:track:10JPsVewvvSmGMbnTrzy6b',
#   'track_href': 'https://api.spotify.com/v1/tracks/10JPsVewvvSmGMbnTrzy6b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10JPsVewvvSmGMbnTrzy6b',
#   'duration_ms': 217373,
#   'time_signature': 4},
#  {'danceability': 0.254,
#   'energy': 0.97,
#   'key': 8,
#   'loudness': -4.635,
#   'mode': 1,
#   'speechiness': 0.0789,
#   'acousticness': 0.00015,
#   'instrumentalness': 0.00586,
#   'liveness': 0.141,
#   'valence': 0.166,
#   'tempo': 99.963,
#   'type': 'audio_features',
#   'id': '12j0llNgqzDutJoT4sdVds',
#   'uri': 'spotify:track:12j0llNgqzDutJoT4sdVds',
#   'track_href': 'https://api.spotify.com/v1/tracks/12j0llNgqzDutJoT4sdVds',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12j0llNgqzDutJoT4sdVds',
#   'duration_ms': 300520,
#   'time_signature': 4},
#  {'danceability': 0.558,
#   'energy': 0.41,
#   'key': 2,
#   'loudness': -9.731,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.274,
#   'instrumentalness': 0.332,
#   'liveness': 0.0978,
#   'valence': 0.156,
#   'tempo': 76.003,
#   'type': 'audio_features',
#   'id': '16o3RO4N802JXnZAEE7yXp',
#   'uri': 'spotify:track:16o3RO4N802JXnZAEE7yXp',
#   'track_href': 'https://api.spotify.com/v1/tracks/16o3RO4N802JXnZAEE7yXp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16o3RO4N802JXnZAEE7yXp',
#   'duration_ms': 194960,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.568,
#   'key': 7,
#   'loudness': -6.309,
#   'mode': 1,
#   'speechiness': 0.0367,
#   'acousticness': 0.0146,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.598,
#   'tempo': 144.924,
#   'type': 'audio_features',
#   'id': '17i2yZOOUHKACl2vNyiHeW',
#   'uri': 'spotify:track:17i2yZOOUHKACl2vNyiHeW',
#   'track_href': 'https://api.spotify.com/v1/tracks/17i2yZOOUHKACl2vNyiHeW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17i2yZOOUHKACl2vNyiHeW',
#   'duration_ms': 233627,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.728,
#   'key': 10,
#   'loudness': -8.333,
#   'mode': 0,
#   'speechiness': 0.0373,
#   'acousticness': 0.232,
#   'instrumentalness': 0.186,
#   'liveness': 0.122,
#   'valence': 0.199,
#   'tempo': 163.964,
#   'type': 'audio_features',
#   'id': '17wy0YEQd6HLPqKz54UJc5',
#   'uri': 'spotify:track:17wy0YEQd6HLPqKz54UJc5',
#   'track_href': 'https://api.spotify.com/v1/tracks/17wy0YEQd6HLPqKz54UJc5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17wy0YEQd6HLPqKz54UJc5',
#   'duration_ms': 415040,
#   'time_signature': 4},
#  {'danceability': 0.374,
#   'energy': 0.867,
#   'key': 2,
#   'loudness': -4.052,
#   'mode': 1,
#   'speechiness': 0.0875,
#   'acousticness': 0.0149,
#   'instrumentalness': 0,
#   'liveness': 0.118,
#   'valence': 0.418,
#   'tempo': 165.061,
#   'type': 'audio_features',
#   'id': '18tAOlaRdq04pqrjB8Lt8D',
#   'uri': 'spotify:track:18tAOlaRdq04pqrjB8Lt8D',
#   'track_href': 'https://api.spotify.com/v1/tracks/18tAOlaRdq04pqrjB8Lt8D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18tAOlaRdq04pqrjB8Lt8D',
#   'duration_ms': 288067,
#   'time_signature': 4},
#  {'danceability': 0.479,
#   'energy': 0.888,
#   'key': 0,
#   'loudness': -5.989,
#   'mode': 0,
#   'speechiness': 0.0628,
#   'acousticness': 0.00114,
#   'instrumentalness': 1.17e-05,
#   'liveness': 0.458,
#   'valence': 0.398,
#   'tempo': 148.037,
#   'type': 'audio_features',
#   'id': '1DRBvB3QNHnpkIdcMgMc2J',
#   'uri': 'spotify:track:1DRBvB3QNHnpkIdcMgMc2J',
#   'track_href': 'https://api.spotify.com/v1/tracks/1DRBvB3QNHnpkIdcMgMc2J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DRBvB3QNHnpkIdcMgMc2J',
#   'duration_ms': 330893,
#   'time_signature': 4},
#  {'danceability': 0.477,
#   'energy': 0.0896,
#   'key': 2,
#   'loudness': -16.929,
#   'mode': 1,
#   'speechiness': 0.0661,
#   'acousticness': 0.684,
#   'instrumentalness': 0.925,
#   'liveness': 0.0999,
#   'valence': 0.422,
#   'tempo': 182.191,
#   'type': 'audio_features',
#   'id': '1DThYRRQ0Hwtn1JeJNAqyK',
#   'uri': 'spotify:track:1DThYRRQ0Hwtn1JeJNAqyK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1DThYRRQ0Hwtn1JeJNAqyK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DThYRRQ0Hwtn1JeJNAqyK',
#   'duration_ms': 130173,
#   'time_signature': 3},
#  {'danceability': 0.275,
#   'energy': 0.184,
#   'key': 3,
#   'loudness': -12.586,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.927,
#   'instrumentalness': 0,
#   'liveness': 0.146,
#   'valence': 0.325,
#   'tempo': 98.781,
#   'type': 'audio_features',
#   'id': '1Hr94ZADw5cfltOCueNNPK',
#   'uri': 'spotify:track:1Hr94ZADw5cfltOCueNNPK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Hr94ZADw5cfltOCueNNPK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Hr94ZADw5cfltOCueNNPK',
#   'duration_ms': 158533,
#   'time_signature': 3},
#  {'danceability': 0.472,
#   'energy': 0.905,
#   'key': 7,
#   'loudness': -3.935,
#   'mode': 0,
#   'speechiness': 0.0651,
#   'acousticness': 0.00399,
#   'instrumentalness': 0.00498,
#   'liveness': 0.384,
#   'valence': 0.242,
#   'tempo': 96.944,
#   'type': 'audio_features',
#   'id': '1QtUT1YLzZ11t0pKImR8dF',
#   'uri': 'spotify:track:1QtUT1YLzZ11t0pKImR8dF',
#   'track_href': 'https://api.spotify.com/v1/tracks/1QtUT1YLzZ11t0pKImR8dF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1QtUT1YLzZ11t0pKImR8dF',
#   'duration_ms': 290427,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.115,
#   'key': 11,
#   'loudness': -19.109,
#   'mode': 1,
#   'speechiness': 0.0471,
#   'acousticness': 0.932,
#   'instrumentalness': 0.00785,
#   'liveness': 0.107,
#   'valence': 0.207,
#   'tempo': 136.456,
#   'type': 'audio_features',
#   'id': '1fQNmEelyTo6woEzeWjiYO',
#   'uri': 'spotify:track:1fQNmEelyTo6woEzeWjiYO',
#   'track_href': 'https://api.spotify.com/v1/tracks/1fQNmEelyTo6woEzeWjiYO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1fQNmEelyTo6woEzeWjiYO',
#   'duration_ms': 218003,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.558,
#   'key': 9,
#   'loudness': -7.662,
#   'mode': 1,
#   'speechiness': 0.304,
#   'acousticness': 0.0657,
#   'instrumentalness': 6.09e-06,
#   'liveness': 0.0753,
#   'valence': 0.68,
#   'tempo': 78.025,
#   'type': 'audio_features',
#   'id': '1pDMMJuFdMcnMBPg0PhRly',
#   'uri': 'spotify:track:1pDMMJuFdMcnMBPg0PhRly',
#   'track_href': 'https://api.spotify.com/v1/tracks/1pDMMJuFdMcnMBPg0PhRly',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1pDMMJuFdMcnMBPg0PhRly',
#   'duration_ms': 207267,
#   'time_signature': 1},
#  {'danceability': 0.819,
#   'energy': 0.563,
#   'key': 6,
#   'loudness': -7.237,
#   'mode': 0,
#   'speechiness': 0.138,
#   'acousticness': 0.0384,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.532,
#   'tempo': 89.988,
#   'type': 'audio_features',
#   'id': '1xGKgGTeLOHtuA1uSOdhFv',
#   'uri': 'spotify:track:1xGKgGTeLOHtuA1uSOdhFv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xGKgGTeLOHtuA1uSOdhFv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xGKgGTeLOHtuA1uSOdhFv',
#   'duration_ms': 236333,
#   'time_signature': 4},
#  {'danceability': 0.535,
#   'energy': 0.378,
#   'key': 11,
#   'loudness': -10.441,
#   'mode': 0,
#   'speechiness': 0.0343,
#   'acousticness': 0.754,
#   'instrumentalness': 1.28e-05,
#   'liveness': 0.0705,
#   'valence': 0.209,
#   'tempo': 118.519,
#   'type': 'audio_features',
#   'id': '1y2PdRopUsttCiSAZKc4M7',
#   'uri': 'spotify:track:1y2PdRopUsttCiSAZKc4M7',
#   'track_href': 'https://api.spotify.com/v1/tracks/1y2PdRopUsttCiSAZKc4M7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1y2PdRopUsttCiSAZKc4M7',
#   'duration_ms': 339560,
#   'time_signature': 4},
#  {'danceability': 0.557,
#   'energy': 0.59,
#   'key': 0,
#   'loudness': -8.686,
#   'mode': 1,
#   'speechiness': 0.035,
#   'acousticness': 0.856,
#   'instrumentalness': 0.000134,
#   'liveness': 0.66,
#   'valence': 0.683,
#   'tempo': 120.743,
#   'type': 'audio_features',
#   'id': '25q5tbgQhfYNKfEOsRhHIG',
#   'uri': 'spotify:track:25q5tbgQhfYNKfEOsRhHIG',
#   'track_href': 'https://api.spotify.com/v1/tracks/25q5tbgQhfYNKfEOsRhHIG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25q5tbgQhfYNKfEOsRhHIG',
#   'duration_ms': 250453,
#   'time_signature': 4},
#  {'danceability': 0.447,
#   'energy': 0.756,
#   'key': 11,
#   'loudness': -10.588,
#   'mode': 1,
#   'speechiness': 0.0315,
#   'acousticness': 0.064,
#   'instrumentalness': 0.942,
#   'liveness': 0.0686,
#   'valence': 0.939,
#   'tempo': 105.057,
#   'type': 'audio_features',
#   'id': '27Cq0RPuH3Hf67hvJ2fOsc',
#   'uri': 'spotify:track:27Cq0RPuH3Hf67hvJ2fOsc',
#   'track_href': 'https://api.spotify.com/v1/tracks/27Cq0RPuH3Hf67hvJ2fOsc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27Cq0RPuH3Hf67hvJ2fOsc',
#   'duration_ms': 231373,
#   'time_signature': 4},
#  {'danceability': 0.522,
#   'energy': 0.919,
#   'key': 9,
#   'loudness': -4.26,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.000119,
#   'instrumentalness': 0.000611,
#   'liveness': 0.331,
#   'valence': 0.675,
#   'tempo': 129.054,
#   'type': 'audio_features',
#   'id': '2FiBiqfMI4CVBp0a2LOoN8',
#   'uri': 'spotify:track:2FiBiqfMI4CVBp0a2LOoN8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2FiBiqfMI4CVBp0a2LOoN8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2FiBiqfMI4CVBp0a2LOoN8',
#   'duration_ms': 184013,
#   'time_signature': 4},
#  {'danceability': 0.321,
#   'energy': 0.67,
#   'key': 1,
#   'loudness': -9.819,
#   'mode': 1,
#   'speechiness': 0.0643,
#   'acousticness': 4.72e-06,
#   'instrumentalness': 0.0132,
#   'liveness': 0.126,
#   'valence': 0.442,
#   'tempo': 117.45,
#   'type': 'audio_features',
#   'id': '2Jm0Y8hynlPTloTu7ncNGz',
#   'uri': 'spotify:track:2Jm0Y8hynlPTloTu7ncNGz',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Jm0Y8hynlPTloTu7ncNGz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Jm0Y8hynlPTloTu7ncNGz',
#   'duration_ms': 203627,
#   'time_signature': 3},
#  {'danceability': 0.706,
#   'energy': 0.747,
#   'key': 11,
#   'loudness': -7.188,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.0138,
#   'instrumentalness': 0.000398,
#   'liveness': 0.322,
#   'valence': 0.625,
#   'tempo': 191.973,
#   'type': 'audio_features',
#   'id': '2Qb8z2uwVq8BbOPpqKh19A',
#   'uri': 'spotify:track:2Qb8z2uwVq8BbOPpqKh19A',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Qb8z2uwVq8BbOPpqKh19A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Qb8z2uwVq8BbOPpqKh19A',
#   'duration_ms': 181493,
#   'time_signature': 4},
#  {'danceability': 0.812,
#   'energy': 0.248,
#   'key': 8,
#   'loudness': -11.129,
#   'mode': 1,
#   'speechiness': 0.0534,
#   'acousticness': 0.986,
#   'instrumentalness': 3.38e-05,
#   'liveness': 0.137,
#   'valence': 0.742,
#   'tempo': 125.33,
#   'type': 'audio_features',
#   'id': '2Y9sTOSdXeEl15NL0MkHWl',
#   'uri': 'spotify:track:2Y9sTOSdXeEl15NL0MkHWl',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Y9sTOSdXeEl15NL0MkHWl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Y9sTOSdXeEl15NL0MkHWl',
#   'duration_ms': 151301,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.547,
#   'key': 4,
#   'loudness': -5.754,
#   'mode': 1,
#   'speechiness': 0.0487,
#   'acousticness': 0.456,
#   'instrumentalness': 0.000257,
#   'liveness': 0.0959,
#   'valence': 0.974,
#   'tempo': 112.606,
#   'type': 'audio_features',
#   'id': '2iqeVsvRh6Nl4h0C8HI2eO',
#   'uri': 'spotify:track:2iqeVsvRh6Nl4h0C8HI2eO',
#   'track_href': 'https://api.spotify.com/v1/tracks/2iqeVsvRh6Nl4h0C8HI2eO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2iqeVsvRh6Nl4h0C8HI2eO',
#   'duration_ms': 237093,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.431,
#   'key': 8,
#   'loudness': -7.296,
#   'mode': 1,
#   'speechiness': 0.0274,
#   'acousticness': 0.0267,
#   'instrumentalness': 0.000116,
#   'liveness': 0.0707,
#   'valence': 0.219,
#   'tempo': 125.927,
#   'type': 'audio_features',
#   'id': '2kC5biNYU0PVFp1WbpEEUG',
#   'uri': 'spotify:track:2kC5biNYU0PVFp1WbpEEUG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2kC5biNYU0PVFp1WbpEEUG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kC5biNYU0PVFp1WbpEEUG',
#   'duration_ms': 286867,
#   'time_signature': 4},
#  {'danceability': 0.54,
#   'energy': 0.832,
#   'key': 9,
#   'loudness': -6.053,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.482,
#   'instrumentalness': 6.29e-06,
#   'liveness': 0.232,
#   'valence': 0.874,
#   'tempo': 82.503,
#   'type': 'audio_features',
#   'id': '2lYJO2V85cfdZVr41z0yiA',
#   'uri': 'spotify:track:2lYJO2V85cfdZVr41z0yiA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2lYJO2V85cfdZVr41z0yiA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lYJO2V85cfdZVr41z0yiA',
#   'duration_ms': 236853,
#   'time_signature': 4},
#  {'danceability': 0.606,
#   'energy': 0.872,
#   'key': 6,
#   'loudness': -6.5,
#   'mode': 0,
#   'speechiness': 0.18,
#   'acousticness': 0.0163,
#   'instrumentalness': 0,
#   'liveness': 0.097,
#   'valence': 0.563,
#   'tempo': 137.519,
#   'type': 'audio_features',
#   'id': '2wzu6qKoHOi209NhQxfEWl',
#   'uri': 'spotify:track:2wzu6qKoHOi209NhQxfEWl',
#   'track_href': 'https://api.spotify.com/v1/tracks/2wzu6qKoHOi209NhQxfEWl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wzu6qKoHOi209NhQxfEWl',
#   'duration_ms': 218427,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.391,
#   'key': 4,
#   'loudness': -6.848,
#   'mode': 1,
#   'speechiness': 0.0388,
#   'acousticness': 0.649,
#   'instrumentalness': 4.07e-06,
#   'liveness': 0.117,
#   'valence': 0.907,
#   'tempo': 119.727,
#   'type': 'audio_features',
#   'id': '2zjcesa9VZEyMxloHcwicp',
#   'uri': 'spotify:track:2zjcesa9VZEyMxloHcwicp',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zjcesa9VZEyMxloHcwicp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zjcesa9VZEyMxloHcwicp',
#   'duration_ms': 159760,
#   'time_signature': 4},
#  {'danceability': 0.714,
#   'energy': 0.529,
#   'key': 7,
#   'loudness': -8.227,
#   'mode': 0,
#   'speechiness': 0.0408,
#   'acousticness': 0.0163,
#   'instrumentalness': 0.000125,
#   'liveness': 0.127,
#   'valence': 0.615,
#   'tempo': 89.299,
#   'type': 'audio_features',
#   'id': '301NQNAFIaPsU5vq0RM9uX',
#   'uri': 'spotify:track:301NQNAFIaPsU5vq0RM9uX',
#   'track_href': 'https://api.spotify.com/v1/tracks/301NQNAFIaPsU5vq0RM9uX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/301NQNAFIaPsU5vq0RM9uX',
#   'duration_ms': 280764,
#   'time_signature': 4},
#  {'danceability': 0.562,
#   'energy': 0.573,
#   'key': 1,
#   'loudness': -8.159,
#   'mode': 0,
#   'speechiness': 0.0327,
#   'acousticness': 0.131,
#   'instrumentalness': 2.39e-06,
#   'liveness': 0.108,
#   'valence': 0.335,
#   'tempo': 122.04,
#   'type': 'audio_features',
#   'id': '31s9fG3lEQ1qMJQJ5qPVqJ',
#   'uri': 'spotify:track:31s9fG3lEQ1qMJQJ5qPVqJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/31s9fG3lEQ1qMJQJ5qPVqJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/31s9fG3lEQ1qMJQJ5qPVqJ',
#   'duration_ms': 240573,
#   'time_signature': 3},
#  {'danceability': 0.468,
#   'energy': 0.833,
#   'key': 0,
#   'loudness': -6.461,
#   'mode': 1,
#   'speechiness': 0.0359,
#   'acousticness': 0.198,
#   'instrumentalness': 0.0534,
#   'liveness': 0.238,
#   'valence': 0.915,
#   'tempo': 116.338,
#   'type': 'audio_features',
#   'id': '329uZrbe0oKjbJZepUjsQ5',
#   'uri': 'spotify:track:329uZrbe0oKjbJZepUjsQ5',
#   'track_href': 'https://api.spotify.com/v1/tracks/329uZrbe0oKjbJZepUjsQ5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/329uZrbe0oKjbJZepUjsQ5',
#   'duration_ms': 353560,
#   'time_signature': 4},
#  {'danceability': 0.944,
#   'energy': 0.737,
#   'key': 4,
#   'loudness': -9.421,
#   'mode': 1,
#   'speechiness': 0.306,
#   'acousticness': 0.332,
#   'instrumentalness': 2.94e-05,
#   'liveness': 0.11,
#   'valence': 0.342,
#   'tempo': 100.02,
#   'type': 'audio_features',
#   'id': '33adH4DEwMI8RA8dfev3J2',
#   'uri': 'spotify:track:33adH4DEwMI8RA8dfev3J2',
#   'track_href': 'https://api.spotify.com/v1/tracks/33adH4DEwMI8RA8dfev3J2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33adH4DEwMI8RA8dfev3J2',
#   'duration_ms': 158400,
#   'time_signature': 4},
#  {'danceability': 0.503,
#   'energy': 0.281,
#   'key': 7,
#   'loudness': -10.107,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.696,
#   'instrumentalness': 0,
#   'liveness': 0.143,
#   'valence': 0.123,
#   'tempo': 72.034,
#   'type': 'audio_features',
#   'id': '381i3bZUfB0d0fM8LrVm9q',
#   'uri': 'spotify:track:381i3bZUfB0d0fM8LrVm9q',
#   'track_href': 'https://api.spotify.com/v1/tracks/381i3bZUfB0d0fM8LrVm9q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/381i3bZUfB0d0fM8LrVm9q',
#   'duration_ms': 216600,
#   'time_signature': 4},
#  {'danceability': 0.472,
#   'energy': 0.91,
#   'key': 11,
#   'loudness': -3.755,
#   'mode': 0,
#   'speechiness': 0.0579,
#   'acousticness': 0.106,
#   'instrumentalness': 0.000149,
#   'liveness': 0.235,
#   'valence': 0.627,
#   'tempo': 158.007,
#   'type': 'audio_features',
#   'id': '3BnqczOKmJoL1ClJuKDELK',
#   'uri': 'spotify:track:3BnqczOKmJoL1ClJuKDELK',
#   'track_href': 'https://api.spotify.com/v1/tracks/3BnqczOKmJoL1ClJuKDELK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BnqczOKmJoL1ClJuKDELK',
#   'duration_ms': 209053,
#   'time_signature': 4},
#  {'danceability': 0.0699,
#   'energy': 0.0204,
#   'key': 4,
#   'loudness': -28.242,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.99,
#   'instrumentalness': 0.905,
#   'liveness': 0.0967,
#   'valence': 0.0424,
#   'tempo': 73.214,
#   'type': 'audio_features',
#   'id': '3V235okE1uKTBeFu9QgvPE',
#   'uri': 'spotify:track:3V235okE1uKTBeFu9QgvPE',
#   'track_href': 'https://api.spotify.com/v1/tracks/3V235okE1uKTBeFu9QgvPE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3V235okE1uKTBeFu9QgvPE',
#   'duration_ms': 269347,
#   'time_signature': 3},
#  {'danceability': 0.134,
#   'energy': 0.0637,
#   'key': 9,
#   'loudness': -18.542,
#   'mode': 1,
#   'speechiness': 0.0472,
#   'acousticness': 0.98,
#   'instrumentalness': 0.94,
#   'liveness': 0.109,
#   'valence': 0.0347,
#   'tempo': 143.942,
#   'type': 'audio_features',
#   'id': '3Y60FrikUPyqB0LQkxxsbf',
#   'uri': 'spotify:track:3Y60FrikUPyqB0LQkxxsbf',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Y60FrikUPyqB0LQkxxsbf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Y60FrikUPyqB0LQkxxsbf',
#   'duration_ms': 332333,
#   'time_signature': 4},
#  {'danceability': 0.591,
#   'energy': 0.961,
#   'key': 1,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.246,
#   'acousticness': 0.0165,
#   'instrumentalness': 0,
#   'liveness': 0.828,
#   'valence': 0.55,
#   'tempo': 139.897,
#   'type': 'audio_features',
#   'id': '3ZSdE70GOJBvbTkBEmSPjD',
#   'uri': 'spotify:track:3ZSdE70GOJBvbTkBEmSPjD',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZSdE70GOJBvbTkBEmSPjD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZSdE70GOJBvbTkBEmSPjD',
#   'duration_ms': 212907,
#   'time_signature': 4},
#  {'danceability': 0.673,
#   'energy': 0.863,
#   'key': 7,
#   'loudness': -5.253,
#   'mode': 0,
#   'speechiness': 0.0567,
#   'acousticness': 0.352,
#   'instrumentalness': 0,
#   'liveness': 0.0405,
#   'valence': 0.854,
#   'tempo': 128.501,
#   'type': 'audio_features',
#   'id': '3ZXmsCJuvRQor26EL8B9s7',
#   'uri': 'spotify:track:3ZXmsCJuvRQor26EL8B9s7',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZXmsCJuvRQor26EL8B9s7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZXmsCJuvRQor26EL8B9s7',
#   'duration_ms': 240613,
#   'time_signature': 4},
#  {'danceability': 0.699,
#   'energy': 0.418,
#   'key': 10,
#   'loudness': -9.112,
#   'mode': 1,
#   'speechiness': 0.0616,
#   'acousticness': 0.821,
#   'instrumentalness': 1.1e-06,
#   'liveness': 0.0849,
#   'valence': 0.698,
#   'tempo': 139.29,
#   'type': 'audio_features',
#   'id': '3fxMVOL4vu230ePLPcBS71',
#   'uri': 'spotify:track:3fxMVOL4vu230ePLPcBS71',
#   'track_href': 'https://api.spotify.com/v1/tracks/3fxMVOL4vu230ePLPcBS71',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3fxMVOL4vu230ePLPcBS71',
#   'duration_ms': 134440,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.566,
#   'key': 7,
#   'loudness': -7.357,
#   'mode': 0,
#   'speechiness': 0.0321,
#   'acousticness': 0.0864,
#   'instrumentalness': 0,
#   'liveness': 0.532,
#   'valence': 0.559,
#   'tempo': 129.951,
#   'type': 'audio_features',
#   'id': '3iC5fiusKNUYVQvFqktnqo',
#   'uri': 'spotify:track:3iC5fiusKNUYVQvFqktnqo',
#   'track_href': 'https://api.spotify.com/v1/tracks/3iC5fiusKNUYVQvFqktnqo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3iC5fiusKNUYVQvFqktnqo',
#   'duration_ms': 310667,
#   'time_signature': 4},
#  {'danceability': 0.598,
#   'energy': 0.749,
#   'key': 6,
#   'loudness': -6.352,
#   'mode': 1,
#   'speechiness': 0.197,
#   'acousticness': 0.694,
#   'instrumentalness': 0,
#   'liveness': 0.198,
#   'valence': 0.483,
#   'tempo': 136.0,
#   'type': 'audio_features',
#   'id': '3wmiVgCEEo8LLkUTtscnYH',
#   'uri': 'spotify:track:3wmiVgCEEo8LLkUTtscnYH',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wmiVgCEEo8LLkUTtscnYH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wmiVgCEEo8LLkUTtscnYH',
#   'duration_ms': 282200,
#   'time_signature': 4},
#  {'danceability': 0.586,
#   'energy': 0.734,
#   'key': 0,
#   'loudness': -7.296,
#   'mode': 1,
#   'speechiness': 0.0351,
#   'acousticness': 0.0848,
#   'instrumentalness': 0.0383,
#   'liveness': 0.245,
#   'valence': 0.47,
#   'tempo': 138.614,
#   'type': 'audio_features',
#   'id': '3zh5fcBt64LRIw5uLvep2w',
#   'uri': 'spotify:track:3zh5fcBt64LRIw5uLvep2w',
#   'track_href': 'https://api.spotify.com/v1/tracks/3zh5fcBt64LRIw5uLvep2w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3zh5fcBt64LRIw5uLvep2w',
#   'duration_ms': 243107,
#   'time_signature': 4},
#  {'danceability': 0.666,
#   'energy': 0.816,
#   'key': 10,
#   'loudness': -5.413,
#   'mode': 0,
#   'speechiness': 0.331,
#   'acousticness': 0.00587,
#   'instrumentalness': 2.9e-06,
#   'liveness': 0.161,
#   'valence': 0.879,
#   'tempo': 91.478,
#   'type': 'audio_features',
#   'id': '42RXS6x3DZGF5v2FxqrChb',
#   'uri': 'spotify:track:42RXS6x3DZGF5v2FxqrChb',
#   'track_href': 'https://api.spotify.com/v1/tracks/42RXS6x3DZGF5v2FxqrChb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/42RXS6x3DZGF5v2FxqrChb',
#   'duration_ms': 163107,
#   'time_signature': 4},
#  {'danceability': 0.425,
#   'energy': 0.285,
#   'key': 9,
#   'loudness': -14.321,
#   'mode': 0,
#   'speechiness': 0.0466,
#   'acousticness': 0.619,
#   'instrumentalness': 2.84e-06,
#   'liveness': 0.0847,
#   'valence': 0.303,
#   'tempo': 145.442,
#   'type': 'audio_features',
#   'id': '47Bnav29zD2TSLeqWW4ZKe',
#   'uri': 'spotify:track:47Bnav29zD2TSLeqWW4ZKe',
#   'track_href': 'https://api.spotify.com/v1/tracks/47Bnav29zD2TSLeqWW4ZKe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47Bnav29zD2TSLeqWW4ZKe',
#   'duration_ms': 704120,
#   'time_signature': 4},
#  {'danceability': 0.424,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -6.517,
#   'mode': 1,
#   'speechiness': 0.0712,
#   'acousticness': 0.129,
#   'instrumentalness': 0,
#   'liveness': 0.476,
#   'valence': 0.394,
#   'tempo': 139.453,
#   'type': 'audio_features',
#   'id': '49J0QmYt43hbNp0G1294iC',
#   'uri': 'spotify:track:49J0QmYt43hbNp0G1294iC',
#   'track_href': 'https://api.spotify.com/v1/tracks/49J0QmYt43hbNp0G1294iC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/49J0QmYt43hbNp0G1294iC',
#   'duration_ms': 387827,
#   'time_signature': 4},
#  {'danceability': 0.245,
#   'energy': 0.445,
#   'key': 2,
#   'loudness': -7.09,
#   'mode': 1,
#   'speechiness': 0.0437,
#   'acousticness': 0.145,
#   'instrumentalness': 0.739,
#   'liveness': 0.177,
#   'valence': 0.236,
#   'tempo': 145.974,
#   'type': 'audio_features',
#   'id': '4AMPduwQPjNsqpz7Mmwn5i',
#   'uri': 'spotify:track:4AMPduwQPjNsqpz7Mmwn5i',
#   'track_href': 'https://api.spotify.com/v1/tracks/4AMPduwQPjNsqpz7Mmwn5i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AMPduwQPjNsqpz7Mmwn5i',
#   'duration_ms': 243480,
#   'time_signature': 4},
#  {'danceability': 0.471,
#   'energy': 0.998,
#   'key': 6,
#   'loudness': -3.232,
#   'mode': 1,
#   'speechiness': 0.192,
#   'acousticness': 0.00158,
#   'instrumentalness': 0.0037,
#   'liveness': 0.979,
#   'valence': 0.0822,
#   'tempo': 170.002,
#   'type': 'audio_features',
#   'id': '4AQ3UW7El4Hu3pJBeQ805r',
#   'uri': 'spotify:track:4AQ3UW7El4Hu3pJBeQ805r',
#   'track_href': 'https://api.spotify.com/v1/tracks/4AQ3UW7El4Hu3pJBeQ805r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AQ3UW7El4Hu3pJBeQ805r',
#   'duration_ms': 196973,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.886,
#   'key': 0,
#   'loudness': -6.291,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.00342,
#   'instrumentalness': 0,
#   'liveness': 0.0681,
#   'valence': 0.74,
#   'tempo': 105.575,
#   'type': 'audio_features',
#   'id': '4JvacMyrylsX8C281ZQ3m9',
#   'uri': 'spotify:track:4JvacMyrylsX8C281ZQ3m9',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JvacMyrylsX8C281ZQ3m9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JvacMyrylsX8C281ZQ3m9',
#   'duration_ms': 274200,
#   'time_signature': 4}]

# %%
## 관련된 아티스트 찾기
sp.artist_related_artists(artist_id='5aIqB5nVVvmFsvSdExz408')
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1QL7yTHrdahRMpvNtn6rI2'},
#    'followers': {'href': None, 'total': 341894},
#    'genres': ['baroque',
#     'classical',
#     'early music',
#     'english baroque',
#     'german baroque'],
#    'href': 'https://api.spotify.com/v1/artists/1QL7yTHrdahRMpvNtn6rI2',
#    'id': '1QL7yTHrdahRMpvNtn6rI2',
#    'images': [{'height': 1209,
#      'url': 'https://i.scdn.co/image/6391390229a5fb88e8e0d71e3e942b427d12d9a8',
#      'width': 1000},
#     {'height': 774,
#      'url': 'https://i.scdn.co/image/80e4fa2aac467af1b0a13201b585ae0ca27367dc',
#      'width': 640},
#     {'height': 242,
#      'url': 'https://i.scdn.co/image/28e3224e9ba32cc880794fc6192b1836b1bcb09a',
#      'width': 200},
#     {'height': 77,
#      'url': 'https://i.scdn.co/image/ce62fd096aa0cc8cd91b12814adde9fb98463c1a',
#      'width': 64}],
#    'name': 'George Frideric Handel',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:1QL7yTHrdahRMpvNtn6rI2'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2QOIawHpSlOwXDvSqQ9YJR'},
#    'followers': {'href': None, 'total': 1110036},
#    'genres': ['baroque', 'classical', 'early music', 'italian baroque'],
#    'href': 'https://api.spotify.com/v1/artists/2QOIawHpSlOwXDvSqQ9YJR',
#    'id': '2QOIawHpSlOwXDvSqQ9YJR',
#    'images': [{'height': 1194,
#      'url': 'https://i.scdn.co/image/9785700bae86f991f78183076861c7342a4bcf90',
#      'width': 1000},
#     {'height': 764,
#      'url': 'https://i.scdn.co/image/12caee0d8c2843b37e2b19da99e385010a2f8c5b',
#      'width': 640},
#     {'height': 239,
#      'url': 'https://i.scdn.co/image/4bdf9bc839ae7d30e69f6399ac47c74c1bd62212',
#      'width': 200},
#     {'height': 76,
#      'url': 'https://i.scdn.co/image/30702c2e565f3c36fcc65673cf2f19fe852ca7c0',
#      'width': 64}],
#    'name': 'Antonio Vivaldi',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:2QOIawHpSlOwXDvSqQ9YJR'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wOqMjp9TyABvtHdOSOTUS'},
#    'followers': {'href': None, 'total': 2529310},
#    'genres': ['classical', 'classical era', 'early romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/2wOqMjp9TyABvtHdOSOTUS',
#    'id': '2wOqMjp9TyABvtHdOSOTUS',
#    'images': [{'height': 750,
#      'url': 'https://i.scdn.co/image/db022999443da6f89e250086329d98b17399b346',
#      'width': 1000},
#     {'height': 480,
#      'url': 'https://i.scdn.co/image/693030b2c7ee75d1fc095d9e6a7fe391a6b10f27',
#      'width': 640},
#     {'height': 150,
#      'url': 'https://i.scdn.co/image/348252c0e6722a55a05484b052ef010e71ca30ce',
#      'width': 200},
#     {'height': 48,
#      'url': 'https://i.scdn.co/image/621f978b2a436b0392478baccb8778d3a9842e38',
#      'width': 64}],
#    'name': 'Ludwig van Beethoven',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:2wOqMjp9TyABvtHdOSOTUS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7y97mc3bZRFXzT2szRM4L4'},
#    'followers': {'href': None, 'total': 1431183},
#    'genres': ['classical', 'early romantic era', 'polish classical'],
#    'href': 'https://api.spotify.com/v1/artists/7y97mc3bZRFXzT2szRM4L4',
#    'id': '7y97mc3bZRFXzT2szRM4L4',
#    'images': [{'height': 905,
#      'url': 'https://i.scdn.co/image/54e56b70836690987d16e535c09c80a91d29e417',
#      'width': 1000},
#     {'height': 579,
#      'url': 'https://i.scdn.co/image/9537ec0e6e6fcedd6c22cb34f593e3be21908ae8',
#      'width': 640},
#     {'height': 181,
#      'url': 'https://i.scdn.co/image/c8740ab4a7d24bf2fad92213cc1e3215539c6145',
#      'width': 200},
#     {'height': 58,
#      'url': 'https://i.scdn.co/image/ac2c86445b627d763321720cc14d90b3fa69e993',
#      'width': 64}],
#    'name': 'Frédéric Chopin',
#    'popularity': 74,
#    'type': 'artist',
#    'uri': 'spotify:artist:7y97mc3bZRFXzT2szRM4L4'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ihY290YPGc3aY2xTyx7Gy'},
#    'followers': {'href': None, 'total': 192617},
#    'genres': ['classical', 'late romantic era', 'norwegian classical'],
#    'href': 'https://api.spotify.com/v1/artists/5ihY290YPGc3aY2xTyx7Gy',
#    'id': '5ihY290YPGc3aY2xTyx7Gy',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/a5dc4df4f87b534afc7b21116bc7680492210656',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/d9d8fdedfd9e68b36e0028d9997f6a9065c09481',
#      'width': 640},
#     {'height': 315,
#      'url': 'https://i.scdn.co/image/9dc1d187b3c797c0f36258faacbc1e723e7c2858',
#      'width': 200},
#     {'height': 101,
#      'url': 'https://i.scdn.co/image/3a1c45a348e4f7115f10f2df6d553e2203882722',
#      'width': 64}],
#    'name': 'Edvard Grieg',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:5ihY290YPGc3aY2xTyx7Gy'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#    'followers': {'href': None, 'total': 2715182},
#    'genres': ['classical', 'classical era'],
#    'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#    'id': '4NJhFmfw43RLBLjQvxDuRS',
#    'images': [{'height': 1470,
#      'url': 'https://i.scdn.co/image/9bf940bd1f89a20b349c0f74d06cff0106532f65',
#      'width': 1000},
#     {'height': 941,
#      'url': 'https://i.scdn.co/image/2f73a3b1dd946111dcef26f2b7f48c7511632266',
#      'width': 640},
#     {'height': 294,
#      'url': 'https://i.scdn.co/image/919b1b65c689fa96bbb1266de20f3e010e773eee',
#      'width': 200},
#     {'height': 94,
#      'url': 'https://i.scdn.co/image/839020265ee16720ffcf5348a1a49272c2ef1c78',
#      'width': 64}],
#    'name': 'Wolfgang Amadeus Mozart',
#    'popularity': 75,
#    'type': 'artist',
#    'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wTAi7QkpP6kp8a54lmTOq'},
#    'followers': {'href': None, 'total': 398286},
#    'genres': ['classical', 'late romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/5wTAi7QkpP6kp8a54lmTOq',
#    'id': '5wTAi7QkpP6kp8a54lmTOq',
#    'images': [{'height': 752,
#      'url': 'https://i.scdn.co/image/d5c6af18beb1411ab49c2976647e0d370bf66a88',
#      'width': 514},
#     {'height': 293,
#      'url': 'https://i.scdn.co/image/841b4adc1a4e66906d99229aaaec26306d6aed92',
#      'width': 200},
#     {'height': 94,
#      'url': 'https://i.scdn.co/image/39d3c79df7fed6b4c597babaa24586d40fa44a45',
#      'width': 64}],
#    'name': 'Johannes Brahms',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:5wTAi7QkpP6kp8a54lmTOq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0OzxPXyowUEQ532c9AmHUR'},
#    'followers': {'href': None, 'total': 162400},
#    'genres': ['classical', 'italian opera', 'post-romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/0OzxPXyowUEQ532c9AmHUR',
#    'id': '0OzxPXyowUEQ532c9AmHUR',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/98aef2b83b0148a90f9c60a163e08197f9d8606b',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/c0a873e1709b857606516f4945316b44f5a8b818',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/d0dd39d8a6205b1fdd445d78a8416e0c87436e1a',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/82e3c5418108791f78ede0bbc90ada9580ee7548',
#      'width': 64}],
#    'name': 'Giacomo Puccini',
#    'popularity': 62,
#    'type': 'artist',
#    'uri': 'spotify:artist:0OzxPXyowUEQ532c9AmHUR'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JOQXgYdQV2yfrhewqx96o'},
#    'followers': {'href': None, 'total': 250592},
#    'genres': ['classical', 'italian opera', 'late romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/1JOQXgYdQV2yfrhewqx96o',
#    'id': '1JOQXgYdQV2yfrhewqx96o',
#    'images': [{'height': 744,
#      'url': 'https://i.scdn.co/image/29dcc5fb26df65b722073e5246c6a430e9968aa7',
#      'width': 586},
#     {'height': 254,
#      'url': 'https://i.scdn.co/image/a1f0ab39a433a3f6b630107d460280502acecec4',
#      'width': 200},
#     {'height': 81,
#      'url': 'https://i.scdn.co/image/d3e0ab29f4a7da7073b7a39d47069de8d4ad634f',
#      'width': 64}],
#    'name': 'Giuseppe Verdi',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:1JOQXgYdQV2yfrhewqx96o'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6n7nd5iceYpXVwcx8VPpxF'},
#    'followers': {'href': None, 'total': 219089},
#    'genres': ['classical', 'late romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/6n7nd5iceYpXVwcx8VPpxF',
#    'id': '6n7nd5iceYpXVwcx8VPpxF',
#    'images': [{'height': 1401,
#      'url': 'https://i.scdn.co/image/f1cd0eea7fb3b75bfad16a10af1dc0dd0763efba',
#      'width': 1000},
#     {'height': 897,
#      'url': 'https://i.scdn.co/image/ca35ee805231ffda36289d7672239a868690d8b5',
#      'width': 640},
#     {'height': 280,
#      'url': 'https://i.scdn.co/image/9ef8aaf1ff4a3d376f3584c6a671102350d59e70',
#      'width': 200},
#     {'height': 90,
#      'url': 'https://i.scdn.co/image/b8311c55a05e2784140cad2473844e0f539eab2b',
#      'width': 64}],
#    'name': 'Antonín Dvořák',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:6n7nd5iceYpXVwcx8VPpxF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Uff91EOsvd99rtAupatMP'},
#    'followers': {'href': None, 'total': 683277},
#    'genres': ['classical', 'post-romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/1Uff91EOsvd99rtAupatMP',
#    'id': '1Uff91EOsvd99rtAupatMP',
#    'images': [{'height': 458,
#      'url': 'https://i.scdn.co/image/5e1155c852578ddf5d2cfea94ccb3a8a65efa882',
#      'width': 387},
#     {'height': 237,
#      'url': 'https://i.scdn.co/image/d9bf00a7a314028df902da1d026a9844a3365d61',
#      'width': 200},
#     {'height': 76,
#      'url': 'https://i.scdn.co/image/155965c396369f20273bc6ba6a14f4185ffad805',
#      'width': 64}],
#    'name': 'Claude Debussy',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:1Uff91EOsvd99rtAupatMP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/17hR0sYHpx7VYTMRfFUOmY'},
#    'followers': {'href': None, 'total': 193025},
#    'genres': ['classical', 'early modern classical', 'post-romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/17hR0sYHpx7VYTMRfFUOmY',
#    'id': '17hR0sYHpx7VYTMRfFUOmY',
#    'images': [{'height': 276,
#      'url': 'https://i.scdn.co/image/0d8f2b3e9ab748e7767fd31ff9386e06e5834e2b',
#      'width': 200},
#     {'height': 88,
#      'url': 'https://i.scdn.co/image/4404ed7696076fd8f990cecdfbbbd4971f370e0f',
#      'width': 64}],
#    'name': 'Maurice Ravel',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:17hR0sYHpx7VYTMRfFUOmY'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF58APd3YV72Ln2eVg710'},
#    'followers': {'href': None, 'total': 220721},
#    'genres': ['classical', 'early romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/6MF58APd3YV72Ln2eVg710',
#    'id': '6MF58APd3YV72Ln2eVg710',
#    'images': [{'height': 508,
#      'url': 'https://i.scdn.co/image/32bf53aa73dbb81c615a91324efea0bcfff4b440',
#      'width': 443},
#     {'height': 229,
#      'url': 'https://i.scdn.co/image/7f30d9306a73a4233125a3e6ef7680f18b7f6b15',
#      'width': 200},
#     {'height': 73,
#      'url': 'https://i.scdn.co/image/b7fd64d9cab12bfc120453780ee6bad0202fc05a',
#      'width': 64}],
#    'name': 'Felix Mendelssohn',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:6MF58APd3YV72Ln2eVg710'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2p0UyoPfYfI76PCStuXfOP'},
#    'followers': {'href': None, 'total': 511409},
#    'genres': ['classical', 'classical era', 'early romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/2p0UyoPfYfI76PCStuXfOP',
#    'id': '2p0UyoPfYfI76PCStuXfOP',
#    'images': [{'height': 1229,
#      'url': 'https://i.scdn.co/image/ffd1ed5399935c49e9c34ba3681a899104998299',
#      'width': 1000},
#     {'height': 787,
#      'url': 'https://i.scdn.co/image/87eea77169f443e253f96c06dd98a631db96b356',
#      'width': 640},
#     {'height': 246,
#      'url': 'https://i.scdn.co/image/b2fb7dbe6300466d49d81501828cc89a062d411d',
#      'width': 200},
#     {'height': 79,
#      'url': 'https://i.scdn.co/image/168779da16912766ecdea068c5e53c946e5db485',
#      'width': 64}],
#    'name': 'Franz Schubert',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:2p0UyoPfYfI76PCStuXfOP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2gClsBep1tt1rv1CN210SO'},
#    'followers': {'href': None, 'total': 94595},
#    'genres': ['classical', 'post-romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/2gClsBep1tt1rv1CN210SO',
#    'id': '2gClsBep1tt1rv1CN210SO',
#    'images': [{'height': 745,
#      'url': 'https://i.scdn.co/image/965d539c15af1d86ec4875f05ec21d32414c3e64',
#      'width': 1000},
#     {'height': 477,
#      'url': 'https://i.scdn.co/image/c0ee11a2481b76687afca183384b45a081eb7993',
#      'width': 640},
#     {'height': 149,
#      'url': 'https://i.scdn.co/image/b628adc617b1cb96963c9f41c9fd46f840a65e48',
#      'width': 200},
#     {'height': 48,
#      'url': 'https://i.scdn.co/image/779d55b7389b4ec732343e193f8a01442bb6ce8b',
#      'width': 64}],
#    'name': 'Gabriel Fauré',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:2gClsBep1tt1rv1CN210SO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5goS0v24Fc1ydjCKQRwtjM'},
#    'followers': {'href': None, 'total': 184181},
#    'genres': ['classical', 'late romantic era', 'operetta'],
#    'href': 'https://api.spotify.com/v1/artists/5goS0v24Fc1ydjCKQRwtjM',
#    'id': '5goS0v24Fc1ydjCKQRwtjM',
#    'images': [{'height': 501,
#      'url': 'https://i.scdn.co/image/7c66e77f061dcfe1da26d682f228d0e957035e8d',
#      'width': 515},
#     {'height': 195,
#      'url': 'https://i.scdn.co/image/e25d4dcb20c3ab9fd0e46291d8b09a1224eb379f',
#      'width': 200},
#     {'height': 62,
#      'url': 'https://i.scdn.co/image/27f8feeab318eecdb0be9e77470905a4e9b890bf',
#      'width': 64}],
#    'name': 'Johann Strauss II',
#    'popularity': 56,
#    'type': 'artist',
#    'uri': 'spotify:artist:5goS0v24Fc1ydjCKQRwtjM'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0mFblCBw0GcoY7zY1P8tzE'},
#    'followers': {'href': None, 'total': 60555},
#    'genres': ['baroque', 'classical', 'early music', 'italian baroque'],
#    'href': 'https://api.spotify.com/v1/artists/0mFblCBw0GcoY7zY1P8tzE',
#    'id': '0mFblCBw0GcoY7zY1P8tzE',
#    'images': [{'height': 1263,
#      'url': 'https://i.scdn.co/image/02dc4bf883736095757701dfb28acc40f5df8216',
#      'width': 1000},
#     {'height': 808,
#      'url': 'https://i.scdn.co/image/4ab7244c869ea68adf7fc45d5c650eea4361afa3',
#      'width': 640},
#     {'height': 253,
#      'url': 'https://i.scdn.co/image/24555ded3f83f0a86ddae3c637ae256794e4d54a',
#      'width': 200},
#     {'height': 81,
#      'url': 'https://i.scdn.co/image/1236427a95ffd921ab90d155dc6b87171bb0edbc',
#      'width': 64}],
#    'name': 'Domenico Scarlatti',
#    'popularity': 52,
#    'type': 'artist',
#    'uri': 'spotify:artist:0mFblCBw0GcoY7zY1P8tzE'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1385hLNbrnbCJGokfH2ac2'},
#    'followers': {'href': None, 'total': 295012},
#    'genres': ['classical', 'late romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/1385hLNbrnbCJGokfH2ac2',
#    'id': '1385hLNbrnbCJGokfH2ac2',
#    'images': [{'height': 1210,
#      'url': 'https://i.scdn.co/image/9ec531e3712e68c72ae3cf06f17e4055a615c4bf',
#      'width': 1000},
#     {'height': 774,
#      'url': 'https://i.scdn.co/image/7717301df596ae1ae992cfb6de694cb3577969bb',
#      'width': 640},
#     {'height': 242,
#      'url': 'https://i.scdn.co/image/73ca423532a8eb9b88a1a9c20e39f1331fa6e873',
#      'width': 200},
#     {'height': 77,
#      'url': 'https://i.scdn.co/image/7d014d4680e419b3f7e4427b1c43f5c5bba21a28',
#      'width': 64}],
#    'name': 'Franz Liszt',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:1385hLNbrnbCJGokfH2ac2'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4XDJurjQCnWLlE7KLZCT9x'},
#    'followers': {'href': None, 'total': 49352},
#    'genres': ['american modern classical', 'classical'],
#    'href': 'https://api.spotify.com/v1/artists/4XDJurjQCnWLlE7KLZCT9x',
#    'id': '4XDJurjQCnWLlE7KLZCT9x',
#    'images': [{'height': 755,
#      'url': 'https://i.scdn.co/image/706c37ad9b22c417bdbff2cc0611c1dcb54fcaa4',
#      'width': 600},
#     {'height': 252,
#      'url': 'https://i.scdn.co/image/3c769debdc2cfa1ff3c7012e614dcd66a8c16cc2',
#      'width': 200},
#     {'height': 81,
#      'url': 'https://i.scdn.co/image/c19c8513de1cb017dfdd84a8af5f2e70db008f8a',
#      'width': 64}],
#    'name': 'Samuel Barber',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:4XDJurjQCnWLlE7KLZCT9x'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/436sYg6CZhNefQJogaXeK0'},
#    'followers': {'href': None, 'total': 146985},
#    'genres': ['classical', 'late romantic era'],
#    'href': 'https://api.spotify.com/v1/artists/436sYg6CZhNefQJogaXeK0',
#    'id': '436sYg6CZhNefQJogaXeK0',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/f565d81f8dcfdec438207f6d8b34689f3489232a',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/8be8940092279bc9d3bd3aef715b830ff4324585',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/8f678a5306adb0c8d446a20b1bf524ea21220e8a',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/be213cf31a1adbdacc67df8b455cbe46e5513bdb',
#      'width': 64}],
#    'name': 'Camille Saint-Saëns',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:436sYg6CZhNefQJogaXeK0'}]}

# %%
sp.categories()
# 연결하려면 토큰이 필요함
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?offset=0&limit=20',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/pop',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'pop',
#     'name': 'Pop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/mood',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/mood-274x274_976986a31ac8c49794cbdc7246fd5ad7_274x274.jpg',
#       'width': 274}],
#     'id': 'mood',
#     'name': 'Mood'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/edm_dance',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/edm-274x274_0ef612604200a9c14995432994455a6d_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'edm_dance',
#     'name': 'Electronic/Dance'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/decades',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/decades_9ad8e458242b2ac8b184e79ef336c455_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'decades',
#     'name': 'Decades'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/hiphop',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/hip-274_0a661854d61e29eace5fe63f73495e68_274x274.jpg',
#       'width': 274}],
#     'id': 'hiphop',
#     'name': 'Hip-Hop'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/chill',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/chill-274x274_4c46374f007813dd10b37e8d8fd35b4b_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'chill',
#     'name': 'Chill'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/workout',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/media/links/workout-274x274.jpg',
#       'width': None}],
#     'id': 'workout',
#     'name': 'Workout'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/party',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/links/partyicon_274x274.jpg',
#       'width': 274}],
#     'id': 'party',
#     'name': 'Party'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/focus',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/genre-images-square-274x274_5e50d72b846a198fcd2ca9b3aef5f0c8_274x274.jpg',
#       'width': 274}],
#     'id': 'focus',
#     'name': 'Focus'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/sleep',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/sleep-274x274_0d4f836af8fab7bf31526968073e671c_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'sleep',
#     'name': 'Sleep'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/rock',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/rock_9ce79e0a4ef901bbd10494f5b855d3cc_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'rock',
#     'name': 'Rock'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/dinner',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/original/dinner_1b6506abba0ba52c54e6d695c8571078_274x274.jpg',
#       'width': 274}],
#     'id': 'dinner',
#     'name': 'Dinner'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/jazz',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/jazz-274x274_d6f407453a1f43d3163c55cca624a764_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'jazz',
#     'name': 'Jazz'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/rnb',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/r-b-274x274_fd56efa72f4f63764b011b68121581d8_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'rnb',
#     'name': 'R&B'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/romance',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/romance-274x274_8100794c94847b6d27858bed6fa4d91b_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'romance',
#     'name': 'Romance'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/indie_alt',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/fe06caf056474bc58862591cd60b57fc.jpeg',
#       'width': None}],
#     'id': 'indie_alt',
#     'name': 'Indie'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/gaming',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/categories/gaming2_274x274.jpg',
#       'width': 274}],
#     'id': 'gaming',
#     'name': 'Gaming'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/soul',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/soul-274x274_266bc900b35dda8956380cffc73a4d8c_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'soul',
#     'name': 'Soul'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/classical',
#     'icons': [{'height': 274,
#       'url': 'https://t.scdn.co/media/derived/classical-274x274_abf78251ff3d90d2ceaf029253ca7cb4_0_0_274_274.jpg',
#       'width': 274}],
#     'id': 'classical',
#     'name': 'Classical'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/categories?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 34}}

# %%
# 새로운 노래
sp.new_releases()
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2auiVi8sUZo17dLy1HwrTU'},
#       'href': 'https://api.spotify.com/v1/artists/2auiVi8sUZo17dLy1HwrTU',
#       'id': '2auiVi8sUZo17dLy1HwrTU',
#       'name': 'Solange',
#       'type': 'artist',
#       'uri': 'spotify:artist:2auiVi8sUZo17dLy1HwrTU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4WF4HvVT7VjGnVjxjoCR6w'},
#     'href': 'https://api.spotify.com/v1/albums/4WF4HvVT7VjGnVjxjoCR6w',
#     'id': '4WF4HvVT7VjGnVjxjoCR6w',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8e9bc2fe9a8c7ef714ac2ce5b24aa7a89036ccc4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/45b1ea5bc8c3682f61e947ff8df924c28a2e0b0b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ebb50e2392ca4d885828e591441a7ef93c266dd0',
#       'width': 64}],
#     'name': 'When I Get Home',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:4WF4HvVT7VjGnVjxjoCR6w'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17lzZA2AlOHwCwFALHttmp'},
#       'href': 'https://api.spotify.com/v1/artists/17lzZA2AlOHwCwFALHttmp',
#       'id': '17lzZA2AlOHwCwFALHttmp',
#       'name': '2 Chainz',
#       'type': 'artist',
#       'uri': 'spotify:artist:17lzZA2AlOHwCwFALHttmp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1BR69wIifGZUSimcuTjWVg'},
#     'href': 'https://api.spotify.com/v1/albums/1BR69wIifGZUSimcuTjWVg',
#     'id': '1BR69wIifGZUSimcuTjWVg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/59ca4990c8f1a930a2d117a76c7b2ab07fa15dcc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/895cf00244c02da96f130e9ddc66d69dcfac14e1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/c8a81f93b44007d917b41f61c05909275632588a',
#       'width': 64}],
#     'name': 'Rap Or Go To The League',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1BR69wIifGZUSimcuTjWVg'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#       'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#       'id': '2FXC3k01G6Gw61bmprjgqS',
#       'name': 'Hozier',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#     'available_markets': ['AU', 'CA', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2c7gFThUYyo2t6ogAgIYNw'},
#     'href': 'https://api.spotify.com/v1/albums/2c7gFThUYyo2t6ogAgIYNw',
#     'id': '2c7gFThUYyo2t6ogAgIYNw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a2b03058e38a10bc431af747cc2f3e9ba448a7ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f8de2b138db2a2a808b578a0fd73e441d5695b1d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/72bbf7251739d09ac82aa6da0d43b9b607af2b86',
#       'width': 64}],
#     'name': 'Wasteland, Baby!',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:2c7gFThUYyo2t6ogAgIYNw'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MCBfE4596Uoi2O4DtmEMz'},
#       'href': 'https://api.spotify.com/v1/artists/4MCBfE4596Uoi2O4DtmEMz',
#       'id': '4MCBfE4596Uoi2O4DtmEMz',
#       'name': 'Juice WRLD',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MCBfE4596Uoi2O4DtmEMz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5CUG3uqs6s3qreS88rq672'},
#     'href': 'https://api.spotify.com/v1/albums/5CUG3uqs6s3qreS88rq672',
#     'id': '5CUG3uqs6s3qreS88rq672',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c0b3a722b1ec4c39b79db593bf8f10f3f169c06c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f5605f0560726db74fc7990f294ebb1a739a2c20',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/64904b6ef5d25d55f4fb89ec79c9818517731aca',
#       'width': 64}],
#     'name': 'Hear Me Calling',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5CUG3uqs6s3qreS88rq672'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6x2LnllRG5uGarZMsD4iO8'},
#       'href': 'https://api.spotify.com/v1/artists/6x2LnllRG5uGarZMsD4iO8',
#       'id': '6x2LnllRG5uGarZMsD4iO8',
#       'name': 'Thomas Rhett',
#       'type': 'artist',
#       'uri': 'spotify:artist:6x2LnllRG5uGarZMsD4iO8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/302VQGTJKXl3wUNxHntBnH'},
#     'href': 'https://api.spotify.com/v1/albums/302VQGTJKXl3wUNxHntBnH',
#     'id': '302VQGTJKXl3wUNxHntBnH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/4ede2142b2c1976453d0e1f033b08d65491fbbd4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/709a1ff972191a68a00b1f43e389df3e621f346e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/61f1723d78532dbf91a0cfb28b61a8ef7debcae3',
#       'width': 64}],
#     'name': 'Look What God Gave Her',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:302VQGTJKXl3wUNxHntBnH'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#       'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#       'id': '1r4hJ1h58CWwUQe3MxPuau',
#       'name': 'Maluma',
#       'type': 'artist',
#       'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Z6UQR992qmvuH2WLBD1pT'},
#     'href': 'https://api.spotify.com/v1/albums/4Z6UQR992qmvuH2WLBD1pT',
#     'id': '4Z6UQR992qmvuH2WLBD1pT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/d726cc546ff5433636827524a52b3dcac1b8655a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/65dea595df19179df8f9371111ee0565c53c305d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/dc81d1620c7401fcaa51e25ec0c47f4310765aff',
#       'width': 64}],
#     'name': 'HP',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4Z6UQR992qmvuH2WLBD1pT'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1pPmIToKXyGdsCF6LmqLmI'},
#       'href': 'https://api.spotify.com/v1/artists/1pPmIToKXyGdsCF6LmqLmI',
#       'id': '1pPmIToKXyGdsCF6LmqLmI',
#       'name': 'Rich The Kid',
#       'type': 'artist',
#       'uri': 'spotify:artist:1pPmIToKXyGdsCF6LmqLmI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4km2LnRqP66ynZSqX4BqkE'},
#     'href': 'https://api.spotify.com/v1/albums/4km2LnRqP66ynZSqX4BqkE',
#     'id': '4km2LnRqP66ynZSqX4BqkE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/29338fc22980e80da77e91ecaa60432d3f188742',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/85f36037729ae4d9f73b027a88d3f5eda805898b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a401bf238714a1faa4ac06f5cf3955df67055b15',
#       'width': 64}],
#     'name': '4 Phones',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4km2LnRqP66ynZSqX4BqkE'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7z2avKuuiMAT4XZJFv8Rvh'},
#       'href': 'https://api.spotify.com/v1/artists/7z2avKuuiMAT4XZJFv8Rvh',
#       'id': '7z2avKuuiMAT4XZJFv8Rvh',
#       'name': 'Tom Walker',
#       'type': 'artist',
#       'uri': 'spotify:artist:7z2avKuuiMAT4XZJFv8Rvh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Qa0qW4ged1J4HGeLXbFsC'},
#     'href': 'https://api.spotify.com/v1/albums/3Qa0qW4ged1J4HGeLXbFsC',
#     'id': '3Qa0qW4ged1J4HGeLXbFsC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/7aed175ffbc1a32e095d6ccb6bbb735c1592d346',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/75024f4681ac141068fa6129adcaa01475a712d5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a61255c0df437a0bd770e7c76092d12046faf18c',
#       'width': 64}],
#     'name': 'What a Time to Be Alive',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:3Qa0qW4ged1J4HGeLXbFsC'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4W0r9HOcuCC6Vh7aze2hwi'},
#     'href': 'https://api.spotify.com/v1/albums/4W0r9HOcuCC6Vh7aze2hwi',
#     'id': '4W0r9HOcuCC6Vh7aze2hwi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/4c20c1367495b513dcdeb91752a9ece4a63167bb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/eff1d5fb5903d2cf739f7760bed776323564c9c6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/cf5770edef018386a296480606d4b6c4f1deabed',
#       'width': 64}],
#     'name': 'Sucker',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4W0r9HOcuCC6Vh7aze2hwi'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#       'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#       'id': '46SHBwWsqBkxI7EeeBEQG7',
#       'name': 'Kodak Black',
#       'type': 'artist',
#       'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#     'available_markets': ['AE',
#      'AU',
#      'BG',
#      'BH',
#      'CA',
#      'CY',
#      'EE',
#      'EG',
#      'FI',
#      'GR',
#      'HK',
#      'ID',
#      'IL',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LT',
#      'LV',
#      'MY',
#      'NZ',
#      'OM',
#      'PH',
#      'PS',
#      'QA',
#      'RO',
#      'SA',
#      'SG',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'VN',
#      'ZA',
#      'AD',
#      'AT',
#      'BE',
#      'CH',
#      'CZ',
#      'DE',
#      'DK',
#      'DZ',
#      'ES',
#      'FR',
#      'HU',
#      'IT',
#      'LI',
#      'LU',
#      'MC',
#      'MT',
#      'NL',
#      'NO',
#      'PL',
#      'SE',
#      'SK',
#      'TN',
#      'GB',
#      'IE',
#      'IS',
#      'MA',
#      'PT',
#      'AR',
#      'BR',
#      'CL',
#      'PY',
#      'UY',
#      'BO',
#      'DO',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5kltcGxaQ7kpkDx05qJlZ0'},
#     'href': 'https://api.spotify.com/v1/albums/5kltcGxaQ7kpkDx05qJlZ0',
#     'id': '5kltcGxaQ7kpkDx05qJlZ0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/761b61dc1aedf27b9a075d8ce961bd88f51c98ea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/e83ba24af4e9784cf6dffd4a33bffec76483b3cb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/9a6380966655fcd1eb99da50641be6fa4e0eed65',
#       'width': 64}],
#     'name': "Pimpin Ain't Eazy",
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:5kltcGxaQ7kpkDx05qJlZ0'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02kJSzxNuaWGqwubyUba0Z'},
#       'href': 'https://api.spotify.com/v1/artists/02kJSzxNuaWGqwubyUba0Z',
#       'id': '02kJSzxNuaWGqwubyUba0Z',
#       'name': 'G-Eazy',
#       'type': 'artist',
#       'uri': 'spotify:artist:02kJSzxNuaWGqwubyUba0Z'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fl1V19tmjt57oBdxXKAjJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Fl1V19tmjt57oBdxXKAjJ',
#       'id': '3Fl1V19tmjt57oBdxXKAjJ',
#       'name': 'Blueface',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Fl1V19tmjt57oBdxXKAjJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0N2i9tYtJ4EZu1s6gHzSkd'},
#     'href': 'https://api.spotify.com/v1/albums/0N2i9tYtJ4EZu1s6gHzSkd',
#     'id': '0N2i9tYtJ4EZu1s6gHzSkd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/fc4c8ea231ed73f5f9174690838fe6cd8aa60e7b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/c786c63940a34b1094903e885071595e94d2ed60',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5fb0deb23058281c53ac8378339565f41e6ac350',
#       'width': 64}],
#     'name': 'West Coast',
#     'release_date': '2019-02-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0N2i9tYtJ4EZu1s6gHzSkd'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sFIWsNpZYqfjUpaCgueju'},
#       'href': 'https://api.spotify.com/v1/artists/6sFIWsNpZYqfjUpaCgueju',
#       'id': '6sFIWsNpZYqfjUpaCgueju',
#       'name': 'Carly Rae Jepsen',
#       'type': 'artist',
#       'uri': 'spotify:artist:6sFIWsNpZYqfjUpaCgueju'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1xqz6l2gObcbw25EqODDCt'},
#     'href': 'https://api.spotify.com/v1/albums/1xqz6l2gObcbw25EqODDCt',
#     'id': '1xqz6l2gObcbw25EqODDCt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/d89c9d521d293a1e8c04b2e7d5115d0c82907c62',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2c588066f0664f74ef7a2ce9439798579b063664',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ddff3a404f00176a9a2007c2d8367905dae68eca',
#       'width': 64}],
#     'name': 'Now That I Found You / No Drug Like Me',
#     'release_date': '2019-02-27',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:1xqz6l2gObcbw25EqODDCt'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/32Aw9aJJoXXC1Vn3zqzJbQ'},
#       'href': 'https://api.spotify.com/v1/artists/32Aw9aJJoXXC1Vn3zqzJbQ',
#       'id': '32Aw9aJJoXXC1Vn3zqzJbQ',
#       'name': 'TV Noise',
#       'type': 'artist',
#       'uri': 'spotify:artist:32Aw9aJJoXXC1Vn3zqzJbQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5R3Hr2cnCCjt220Jmt2xLf'},
#       'href': 'https://api.spotify.com/v1/artists/5R3Hr2cnCCjt220Jmt2xLf',
#       'id': '5R3Hr2cnCCjt220Jmt2xLf',
#       'name': 'Dillon Francis',
#       'type': 'artist',
#       'uri': 'spotify:artist:5R3Hr2cnCCjt220Jmt2xLf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Uep7LKPuG9SYGgwW4E86j'},
#     'href': 'https://api.spotify.com/v1/albums/1Uep7LKPuG9SYGgwW4E86j',
#     'id': '1Uep7LKPuG9SYGgwW4E86j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9c96a74261d57decfba4e40090b3804fb7b0912a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/1590afe8fa6b0c373037a57ce9a44999e4e4bf2a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b707797d38cea48c2b51bfd08559af6a1bfb1a32',
#       'width': 64}],
#     'name': 'EDM O’ CLOCK',
#     'release_date': '2019-02-27',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1Uep7LKPuG9SYGgwW4E86j'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FQqZYVfTNQ1pCqfkwVFEa'},
#       'href': 'https://api.spotify.com/v1/artists/6FQqZYVfTNQ1pCqfkwVFEa',
#       'id': '6FQqZYVfTNQ1pCqfkwVFEa',
#       'name': 'Foals',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FQqZYVfTNQ1pCqfkwVFEa'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/07gCUMxuIKJkdklcy1IYWa'},
#     'href': 'https://api.spotify.com/v1/albums/07gCUMxuIKJkdklcy1IYWa',
#     'id': '07gCUMxuIKJkdklcy1IYWa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/91534a6b87f8173689506ac05f20acdc479859b7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/52162c9c34ac48b34f53921bd26f1ab8ce0a90ae',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/4ea9fb9ba7ddd062a4d0dc43a5520109e5a30529',
#       'width': 64}],
#     'name': 'Sunday',
#     'release_date': '2019-02-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:07gCUMxuIKJkdklcy1IYWa'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qGkLCMQkNGOJ079iEcC5k'},
#       'href': 'https://api.spotify.com/v1/artists/6qGkLCMQkNGOJ079iEcC5k',
#       'id': '6qGkLCMQkNGOJ079iEcC5k',
#       'name': 'Ben Platt',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qGkLCMQkNGOJ079iEcC5k'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/79tcjby0YSQUPztfie075y'},
#     'href': 'https://api.spotify.com/v1/albums/79tcjby0YSQUPztfie075y',
#     'id': '79tcjby0YSQUPztfie075y',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5f8fe741eebe7ade1d64c4683f948d287f376053',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/18d330f9b681802c094a7040588e8370e1273e3d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/9b307b512de66eeb084ddaf0f77790d03a4e4d3a',
#       'width': 64}],
#     'name': 'Grow As We Go',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:79tcjby0YSQUPztfie075y'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#       'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#       'id': '0pCNk4D3E2xtszsm6hMsWr',
#       'name': 'K.Flay',
#       'type': 'artist',
#       'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3VJmwr78jZW2NIU6ONGkpu'},
#     'href': 'https://api.spotify.com/v1/albums/3VJmwr78jZW2NIU6ONGkpu',
#     'id': '3VJmwr78jZW2NIU6ONGkpu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/2d344f1a214a4bdc34384b924d280d1b6cf2d84d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/8866daf6734e333d35824163553b5bbd04325f3c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/cf673fb0d3d0b5e2e8caa3956b3fe9af07d5f300',
#       'width': 64}],
#     'name': 'Bad Vibes',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3VJmwr78jZW2NIU6ONGkpu'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/10gzBoINW3cLJfZUka8Zoe'},
#       'href': 'https://api.spotify.com/v1/artists/10gzBoINW3cLJfZUka8Zoe',
#       'id': '10gzBoINW3cLJfZUka8Zoe',
#       'name': 'Above & Beyond',
#       'type': 'artist',
#       'uri': 'spotify:artist:10gzBoINW3cLJfZUka8Zoe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0SfsnGyD8FpIN4U4WCkBZ5'},
#       'href': 'https://api.spotify.com/v1/artists/0SfsnGyD8FpIN4U4WCkBZ5',
#       'id': '0SfsnGyD8FpIN4U4WCkBZ5',
#       'name': 'Armin van Buuren',
#       'type': 'artist',
#       'uri': 'spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6CRr9qtC3ApJO9Qd1XKfB2'},
#     'href': 'https://api.spotify.com/v1/albums/6CRr9qtC3ApJO9Qd1XKfB2',
#     'id': '6CRr9qtC3ApJO9Qd1XKfB2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/2fb196fa11675f6644f249f88c43869ff74c717d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6b4261716ac77f1a5c4df2a1341d400749f42298',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/7293a0c5d49d43d298376ab593502d0d8a7fd4a0',
#       'width': 64}],
#     'name': 'Show Me Love',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6CRr9qtC3ApJO9Qd1XKfB2'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rlS0SzVFk8BoiAW0fGBbN'},
#       'href': 'https://api.spotify.com/v1/artists/0rlS0SzVFk8BoiAW0fGBbN',
#       'id': '0rlS0SzVFk8BoiAW0fGBbN',
#       'name': 'Salaam Remi',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rlS0SzVFk8BoiAW0fGBbN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5myfLineN3bGoZRVynH8NM'},
#     'href': 'https://api.spotify.com/v1/albums/5myfLineN3bGoZRVynH8NM',
#     'id': '5myfLineN3bGoZRVynH8NM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/d3adf66164fac92bc144bbdadeb0e32c108b383f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/edf6cb1936d2692441bd13bb6a70864538a61e28',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/9083c906fc2ef9d948a39f82fa092a169565a35c',
#       'width': 64}],
#     'name': 'Roll The Dice',
#     'release_date': '2019-02-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5myfLineN3bGoZRVynH8NM'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo'},
#       'href': 'https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo',
#       'id': '7d3WFRME3vBY2cgoP38RDo',
#       'name': 'Lil Skies',
#       'type': 'artist',
#       'uri': 'spotify:artist:7d3WFRME3vBY2cgoP38RDo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/47FalEKu0of8GExDtZBkxT'},
#     'href': 'https://api.spotify.com/v1/albums/47FalEKu0of8GExDtZBkxT',
#     'id': '47FalEKu0of8GExDtZBkxT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/509a2a43aa2cecbff8b7e6a318ae390ee532c48f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/0c1f36f8bc6d97e163dfdd09b2fe4a6805a10fbb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b52301ea2aaa6235e504cd0e196834b3d8cd0212',
#       'width': 64}],
#     'name': 'Shelby',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:47FalEKu0of8GExDtZBkxT'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72FO0BvoMxHvbQwbNrKqtj'},
#       'href': 'https://api.spotify.com/v1/artists/72FO0BvoMxHvbQwbNrKqtj',
#       'id': '72FO0BvoMxHvbQwbNrKqtj',
#       'name': 'Mary Bragg',
#       'type': 'artist',
#       'uri': 'spotify:artist:72FO0BvoMxHvbQwbNrKqtj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0KCa9BfM1VLKSzfxfM4EPk'},
#     'href': 'https://api.spotify.com/v1/albums/0KCa9BfM1VLKSzfxfM4EPk',
#     'id': '0KCa9BfM1VLKSzfxfM4EPk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/92cdd609ddd6ee676fe822157d64ca21c4688932',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/9a7e508ae3df2e24d54665ded6da40b14b389c3b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b9098c41e16dece14737a80c42e50c2bac3e8292',
#       'width': 64}],
#     'name': 'Violets as Camouflage',
#     'release_date': '2019-03-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:0KCa9BfM1VLKSzfxfM4EPk'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 500}}

# %%
# 
sp.albums(albums='37LUBeVwoGFQOvBhRPNV13')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     118         try:
# --> 119             r.raise_for_status()
#     120         except:
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/albums/?ids=3,7,L,U,B,e,V,w,o,G,F,Q,O,v,B,h,R,P,N,V,1,3
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-33-68e9c62c8965> in <module>
#       1 #
# ----> 2 sp.albums(albums='37LUBeVwoGFQOvBhRPNV13')
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in albums(self, albums)
#     324
#     325         tlist = [self._get_id('album', a) for a in albums]
# --> 326         return self._get('albums/?ids=' + ','.join(tlist))
#     327
#     328     def search(self, q, limit=10, offset=0, type='track', market=None):
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     122                 raise SpotifyException(r.status_code,
#     123                     -1, '%s:\n %s' % (r.url, r.json()['error']['message']),
# --> 124                     headers=r.headers)
#     125             else:
#     126                 raise SpotifyException(r.status_code,
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/albums/?ids=3,7,L,U,B,e,V,w,o,G,F,Q,O,v,B,h,R,P,N,V,1,3:
#  too many ids requested

# %%
# 아티스트의 인기트랙
sp.artist_top_tracks(artist_id='5aIqB5nVVvmFsvSdExz408')
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Dl3HXZjG6ZOWT5cV375lk'},
#       'href': 'https://api.spotify.com/v1/artists/5Dl3HXZjG6ZOWT5cV375lk',
#       'id': '5Dl3HXZjG6ZOWT5cV375lk',
#       'name': 'Yo-Yo Ma',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Dl3HXZjG6ZOWT5cV375lk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2OpnKgmVYPEN2GldgBponI'},
#     'href': 'https://api.spotify.com/v1/albums/2OpnKgmVYPEN2GldgBponI',
#     'id': '2OpnKgmVYPEN2GldgBponI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/71c77a34bbed1b97c53f3ac9b5890bd21a8c610d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ceb39d0ef9d1566fb475a03f59e7669ba9ee1bf7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab4a6d464a058bc158d76c5633fd5b3cf98f2e17',
#       'width': 64}],
#     'name': 'Bach: Cello Suites Nos. 1-6, BWV 1007-1012',
#     'release_date': '1983',
#     'release_date_precision': 'year',
#     'total_tracks': 36,
#     'type': 'album',
#     'uri': 'spotify:album:2OpnKgmVYPEN2GldgBponI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Dl3HXZjG6ZOWT5cV375lk'},
#      'href': 'https://api.spotify.com/v1/artists/5Dl3HXZjG6ZOWT5cV375lk',
#      'id': '5Dl3HXZjG6ZOWT5cV375lk',
#      'name': 'Yo-Yo Ma',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Dl3HXZjG6ZOWT5cV375lk'}],
#    'disc_number': 1,
#    'duration_ms': 151480,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM18200515'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/61dYvvfIRtIDFuqZypPAta'},
#    'href': 'https://api.spotify.com/v1/tracks/61dYvvfIRtIDFuqZypPAta',
#    'id': '61dYvvfIRtIDFuqZypPAta',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cello Suite No. 1 in G Major, BWV 1007: I. Prélude',
#    'popularity': 65,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b4c714f0fcb97a6558dbbc15ece4e283ee494d63?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:61dYvvfIRtIDFuqZypPAta'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/13dkPjqmbcchm8cXjEJQeP'},
#       'href': 'https://api.spotify.com/v1/artists/13dkPjqmbcchm8cXjEJQeP',
#       'id': '13dkPjqmbcchm8cXjEJQeP',
#       'name': 'Glenn Gould',
#       'type': 'artist',
#       'uri': 'spotify:artist:13dkPjqmbcchm8cXjEJQeP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1aCpHSQE5ghxibsQ5gkBe0'},
#     'href': 'https://api.spotify.com/v1/albums/1aCpHSQE5ghxibsQ5gkBe0',
#     'id': '1aCpHSQE5ghxibsQ5gkBe0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a95d8441d20b598ceca39dc89ca3bd90aa249797',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/b178a087f61fb0384a3f957d8a8639140977b687',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/3a58ed58f3f50e9a5e5bdbbdcb79ef1dda974388',
#       'width': 64}],
#     'name': 'Bach: The Goldberg Variations, BWV 988 (1981) - Gould Remastered',
#     'release_date': '1981',
#     'release_date_precision': 'year',
#     'total_tracks': 32,
#     'type': 'album',
#     'uri': 'spotify:album:1aCpHSQE5ghxibsQ5gkBe0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/13dkPjqmbcchm8cXjEJQeP'},
#      'href': 'https://api.spotify.com/v1/artists/13dkPjqmbcchm8cXjEJQeP',
#      'id': '13dkPjqmbcchm8cXjEJQeP',
#      'name': 'Glenn Gould',
#      'type': 'artist',
#      'uri': 'spotify:artist:13dkPjqmbcchm8cXjEJQeP'}],
#    'disc_number': 1,
#    'duration_ms': 184853,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM11409807'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5bu9A6uphPWg39RC3ZKeku'},
#    'href': 'https://api.spotify.com/v1/tracks/5bu9A6uphPWg39RC3ZKeku',
#    'id': '5bu9A6uphPWg39RC3ZKeku',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Goldberg Variations, BWV 988: Aria - Remastered',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b0fc27343a7c115a83cc44c865331082feda9432?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5bu9A6uphPWg39RC3ZKeku'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Dl3HXZjG6ZOWT5cV375lk'},
#       'href': 'https://api.spotify.com/v1/artists/5Dl3HXZjG6ZOWT5cV375lk',
#       'id': '5Dl3HXZjG6ZOWT5cV375lk',
#       'name': 'Yo-Yo Ma',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Dl3HXZjG6ZOWT5cV375lk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6XaCGjrIRFiS5D5IVg66vb'},
#     'href': 'https://api.spotify.com/v1/albums/6XaCGjrIRFiS5D5IVg66vb',
#     'id': '6XaCGjrIRFiS5D5IVg66vb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/bc7dae1868c642f0aa5e0e8d4223ed6f84127205',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2bd803e2252677c23c103e0052f9b4aad44ad69b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/4ffb0e71dd4dda05e50cf39607ca97ccb4f43e35',
#       'width': 64}],
#     'name': 'Six Evolutions - Bach: Cello Suites',
#     'release_date': '2018-08-17',
#     'release_date_precision': 'day',
#     'total_tracks': 36,
#     'type': 'album',
#     'uri': 'spotify:album:6XaCGjrIRFiS5D5IVg66vb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Dl3HXZjG6ZOWT5cV375lk'},
#      'href': 'https://api.spotify.com/v1/artists/5Dl3HXZjG6ZOWT5cV375lk',
#      'id': '5Dl3HXZjG6ZOWT5cV375lk',
#      'name': 'Yo-Yo Ma',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Dl3HXZjG6ZOWT5cV375lk'}],
#    'disc_number': 1,
#    'duration_ms': 150973,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQX91801089'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5mRrklQD0rvuN6sV10HfPn'},
#    'href': 'https://api.spotify.com/v1/tracks/5mRrklQD0rvuN6sV10HfPn',
#    'id': '5mRrklQD0rvuN6sV10HfPn',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Unaccompanied Cello Suite No. 1 in G Major, BWV 1007: I. Prélude',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7e0e0e96b5e76dcd635616b9153eeefe73c7b356?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5mRrklQD0rvuN6sV10HfPn'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YZhNFBxkEB5UKTgMDvot4'},
#       'href': 'https://api.spotify.com/v1/artists/1YZhNFBxkEB5UKTgMDvot4',
#       'id': '1YZhNFBxkEB5UKTgMDvot4',
#       'name': 'Lang Lang',
#       'type': 'artist',
#       'uri': 'spotify:artist:1YZhNFBxkEB5UKTgMDvot4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fopqZRJz4oYR3ftxBAUWy'},
#     'href': 'https://api.spotify.com/v1/albums/2fopqZRJz4oYR3ftxBAUWy',
#     'id': '2fopqZRJz4oYR3ftxBAUWy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/28000ec68a6c517a44e07db90410adeb70583a68',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/a9f985c957c666c2543dabe7bdb222bf25e2ec81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e2cb098998ed62f69c70b2984057ede0be3a6553',
#       'width': 64}],
#     'name': 'Gran Turismo 5 (Original Game Soundtrack)',
#     'release_date': '2010-11-26',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2fopqZRJz4oYR3ftxBAUWy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1YZhNFBxkEB5UKTgMDvot4'},
#      'href': 'https://api.spotify.com/v1/artists/1YZhNFBxkEB5UKTgMDvot4',
#      'id': '1YZhNFBxkEB5UKTgMDvot4',
#      'name': 'Lang Lang',
#      'type': 'artist',
#      'uri': 'spotify:artist:1YZhNFBxkEB5UKTgMDvot4'}],
#    'disc_number': 1,
#    'duration_ms': 327080,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM11004840'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ksxLnn1ymLGRKnwhba45Y'},
#    'href': 'https://api.spotify.com/v1/tracks/4ksxLnn1ymLGRKnwhba45Y',
#    'id': '4ksxLnn1ymLGRKnwhba45Y',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Orchestral Suite No. 3 in D Major, BWV 1068: II. Air "On a G String" (Arr. for Piano)',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c13604ff72081d4762bbaf2ef0810e2a8d970765?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4ksxLnn1ymLGRKnwhba45Y'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/24K6LTZFqBAvKsorwK0iXd'},
#       'href': 'https://api.spotify.com/v1/artists/24K6LTZFqBAvKsorwK0iXd',
#       'id': '24K6LTZFqBAvKsorwK0iXd',
#       'name': 'András Schiff',
#       'type': 'artist',
#       'uri': 'spotify:artist:24K6LTZFqBAvKsorwK0iXd'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0FVPuKxHqRQ2jtmfdFHjI2'},
#     'href': 'https://api.spotify.com/v1/albums/0FVPuKxHqRQ2jtmfdFHjI2',
#     'id': '0FVPuKxHqRQ2jtmfdFHjI2',
#     'images': [{'height': 635,
#       'url': 'https://i.scdn.co/image/8010e9acefe116c26b3357ad5f099fe1bf6b56ca',
#       'width': 640},
#      {'height': 297,
#       'url': 'https://i.scdn.co/image/c97ae185ed43247f00ee5b782086a00eef6ca8e8',
#       'width': 300},
#      {'height': 63,
#       'url': 'https://i.scdn.co/image/72e77c0b1af6d8b990d3b27f2e06c7a3159034a5',
#       'width': 64}],
#     'name': 'Bach, J.S.: Das Wohltemperierte Klavier I',
#     'release_date': '1984-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 24,
#     'type': 'album',
#     'uri': 'spotify:album:0FVPuKxHqRQ2jtmfdFHjI2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/24K6LTZFqBAvKsorwK0iXd'},
#      'href': 'https://api.spotify.com/v1/artists/24K6LTZFqBAvKsorwK0iXd',
#      'id': '24K6LTZFqBAvKsorwK0iXd',
#      'name': 'András Schiff',
#      'type': 'artist',
#      'uri': 'spotify:artist:24K6LTZFqBAvKsorwK0iXd'}],
#    'disc_number': 1,
#    'duration_ms': 233666,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBF078440901'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2XxC430QMotGdympDP1aBo'},
#    'href': 'https://api.spotify.com/v1/tracks/2XxC430QMotGdympDP1aBo',
#    'id': '2XxC430QMotGdympDP1aBo',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Prelude and Fugue in C (WTK, Book I, No.1), BWV 846',
#    'popularity': 59,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2XxC430QMotGdympDP1aBo'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ncNdxBc8zVWMOF7nJ5Pgy'},
#       'href': 'https://api.spotify.com/v1/artists/6ncNdxBc8zVWMOF7nJ5Pgy',
#       'id': '6ncNdxBc8zVWMOF7nJ5Pgy',
#       'name': 'Leon Fleisher',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ncNdxBc8zVWMOF7nJ5Pgy'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3DfJIkZx34132XJ7j1L43O'},
#     'href': 'https://api.spotify.com/v1/albums/3DfJIkZx34132XJ7j1L43O',
#     'id': '3DfJIkZx34132XJ7j1L43O',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e3b0cd96450de423457c2d69fd2e7d9d8cb87cc6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d031015ecd849d5401eab15064b3175870333c79',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b88c29d32ed0873fb7f72656bdf9926133d60518',
#       'width': 64}],
#     'name': 'Two Hands',
#     'release_date': '2004',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3DfJIkZx34132XJ7j1L43O'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ncNdxBc8zVWMOF7nJ5Pgy'},
#      'href': 'https://api.spotify.com/v1/artists/6ncNdxBc8zVWMOF7nJ5Pgy',
#      'id': '6ncNdxBc8zVWMOF7nJ5Pgy',
#      'name': 'Leon Fleisher',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ncNdxBc8zVWMOF7nJ5Pgy'}],
#    'disc_number': 1,
#    'duration_ms': 295840,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT50426104'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7wEql4SrP9nL5U4zxmcrVM'},
#    'href': 'https://api.spotify.com/v1/tracks/7wEql4SrP9nL5U4zxmcrVM',
#    'id': '7wEql4SrP9nL5U4zxmcrVM',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sheep May Safely Graze',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0a37f8ba89070ffe2952733a8c011dac16bfa16e?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7wEql4SrP9nL5U4zxmcrVM'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fJKxKjBxD1X1NkkG78qai'},
#       'href': 'https://api.spotify.com/v1/artists/2fJKxKjBxD1X1NkkG78qai',
#       'id': '2fJKxKjBxD1X1NkkG78qai',
#       'name': 'Freiburger Barockorchester',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fJKxKjBxD1X1NkkG78qai'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0JGI98ag3YDbM9SCHcnKXg'},
#       'href': 'https://api.spotify.com/v1/artists/0JGI98ag3YDbM9SCHcnKXg',
#       'id': '0JGI98ag3YDbM9SCHcnKXg',
#       'name': 'Petra Mullejans',
#       'type': 'artist',
#       'uri': 'spotify:artist:0JGI98ag3YDbM9SCHcnKXg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Jq1SP0L2atkSMv5wNOU66'},
#       'href': 'https://api.spotify.com/v1/artists/4Jq1SP0L2atkSMv5wNOU66',
#       'id': '4Jq1SP0L2atkSMv5wNOU66',
#       'name': 'Gottfried Von Der Goltz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Jq1SP0L2atkSMv5wNOU66'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6EIwQjGHbMF52ktfBUWiCG'},
#       'href': 'https://api.spotify.com/v1/artists/6EIwQjGHbMF52ktfBUWiCG',
#       'id': '6EIwQjGHbMF52ktfBUWiCG',
#       'name': 'Anne-Katharina Schreiber',
#       'type': 'artist',
#       'uri': 'spotify:artist:6EIwQjGHbMF52ktfBUWiCG'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3S6qaM2ijmVtz68R6QMlPs'},
#     'href': 'https://api.spotify.com/v1/albums/3S6qaM2ijmVtz68R6QMlPs',
#     'id': '3S6qaM2ijmVtz68R6QMlPs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/349233b69c00443027d16d3c09092ac36800bb6e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/dc3269f68836ace8f3922316fadad90e2e3119c4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/53c3918f85f1dd946b234b4f1f6560c9c58a8780',
#       'width': 64}],
#     'name': 'Bach: Violin Concertos',
#     'release_date': '2013-03-25',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3S6qaM2ijmVtz68R6QMlPs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fJKxKjBxD1X1NkkG78qai'},
#      'href': 'https://api.spotify.com/v1/artists/2fJKxKjBxD1X1NkkG78qai',
#      'id': '2fJKxKjBxD1X1NkkG78qai',
#      'name': 'Freiburger Barockorchester',
#      'type': 'artist',
#      'uri': 'spotify:artist:2fJKxKjBxD1X1NkkG78qai'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Jq1SP0L2atkSMv5wNOU66'},
#      'href': 'https://api.spotify.com/v1/artists/4Jq1SP0L2atkSMv5wNOU66',
#      'id': '4Jq1SP0L2atkSMv5wNOU66',
#      'name': 'Gottfried Von Der Goltz',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Jq1SP0L2atkSMv5wNOU66'}],
#    'disc_number': 1,
#    'duration_ms': 453506,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRZ141208040'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3nxaPqAOxUxkLhIhbvmv4t'},
#    'href': 'https://api.spotify.com/v1/tracks/3nxaPqAOxUxkLhIhbvmv4t',
#    'id': '3nxaPqAOxUxkLhIhbvmv4t',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Violin Concerto BWV 1042 in E Major: Violin Concerto BWV 1042 in E Major: I. Allegro',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c4fc99a73209820269c6d9eebbb9754c2ed676e6?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3nxaPqAOxUxkLhIhbvmv4t'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VzF0TRE4XHQiTqDrEmvW1'},
#       'href': 'https://api.spotify.com/v1/artists/0VzF0TRE4XHQiTqDrEmvW1',
#       'id': '0VzF0TRE4XHQiTqDrEmvW1',
#       'name': 'Anne Queffélec',
#       'type': 'artist',
#       'uri': 'spotify:artist:0VzF0TRE4XHQiTqDrEmvW1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/02Koa96QFRsejQDA39Widn'},
#     'href': 'https://api.spotify.com/v1/albums/02Koa96QFRsejQDA39Widn',
#     'id': '02Koa96QFRsejQDA39Widn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/3f37c704fd0fc4c04af2753668e669d3eb401230',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6dfc3daebbe86741bef3a8f55ee6c75d47bc70bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5970dd4617cc4ecd1f7825452c0eef94ab4040aa',
#       'width': 64}],
#     'name': 'Bach: Contemplation',
#     'release_date': '2009-01-27',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:02Koa96QFRsejQDA39Widn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VzF0TRE4XHQiTqDrEmvW1'},
#      'href': 'https://api.spotify.com/v1/artists/0VzF0TRE4XHQiTqDrEmvW1',
#      'id': '0VzF0TRE4XHQiTqDrEmvW1',
#      'name': 'Anne Queffélec',
#      'type': 'artist',
#      'uri': 'spotify:artist:0VzF0TRE4XHQiTqDrEmvW1'}],
#    'disc_number': 1,
#    'duration_ms': 209600,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRU620808217'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0p6eXDSAFhKm9CB192DLeB'},
#    'href': 'https://api.spotify.com/v1/tracks/0p6eXDSAFhKm9CB192DLeB',
#    'id': '0p6eXDSAFhKm9CB192DLeB',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Choral "Jesu, meine Freude" de la Cantate "Herz und Mund Tat und Leben" en sol majeur, BWV 147',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7d776d56886b4761cbc2b400e8e8c73e81b58f1b?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:0p6eXDSAFhKm9CB192DLeB'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#       'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#       'id': '5aIqB5nVVvmFsvSdExz408',
#       'name': 'Johann Sebastian Bach',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/25mbgceDJKxXGP8c5FmC83'},
#       'href': 'https://api.spotify.com/v1/artists/25mbgceDJKxXGP8c5FmC83',
#       'id': '25mbgceDJKxXGP8c5FmC83',
#       'name': 'Trevor Pinnock',
#       'type': 'artist',
#       'uri': 'spotify:artist:25mbgceDJKxXGP8c5FmC83'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0ZWboVnn5YWjPEB79FCwWV'},
#     'href': 'https://api.spotify.com/v1/albums/0ZWboVnn5YWjPEB79FCwWV',
#     'id': '0ZWboVnn5YWjPEB79FCwWV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/08e700fe432fe9f8fc4b2ca90d43d20cc77b66f3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/799a281f1b67ad385434210a10128b452565bd0b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e425b96ab2bdf5c22db0583fd758546e0164bf00',
#       'width': 64}],
#     'name': 'Bach: Six Concertos for the Margrave of Brandenburg',
#     'release_date': '2008-01-03',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:0ZWboVnn5YWjPEB79FCwWV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/25mbgceDJKxXGP8c5FmC83'},
#      'href': 'https://api.spotify.com/v1/artists/25mbgceDJKxXGP8c5FmC83',
#      'id': '25mbgceDJKxXGP8c5FmC83',
#      'name': 'Trevor Pinnock',
#      'type': 'artist',
#      'uri': 'spotify:artist:25mbgceDJKxXGP8c5FmC83'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2T2bi3cWva2cY4A3FMGVzZ'},
#      'href': 'https://api.spotify.com/v1/artists/2T2bi3cWva2cY4A3FMGVzZ',
#      'id': '2T2bi3cWva2cY4A3FMGVzZ',
#      'name': 'European Brandenburg Ensemble',
#      'type': 'artist',
#      'uri': 'spotify:artist:2T2bi3cWva2cY4A3FMGVzZ'}],
#    'disc_number': 1,
#    'duration_ms': 332320,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBELX0702560'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4tXktBBrKGTebkYjvzFA3i'},
#    'href': 'https://api.spotify.com/v1/tracks/4tXktBBrKGTebkYjvzFA3i',
#    'id': '4tXktBBrKGTebkYjvzFA3i',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Brandenburg Concerto No. 3 in G Major, BWV 1048: I. [Allegro]',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/eb48b87db5b9b07aa0ac5e6af87f8c940dd16e05?cid=18036c9769a64a9488a17419863beb3b',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4tXktBBrKGTebkYjvzFA3i'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35pZsti1RSA5Zv98jAm8kX'},
#       'href': 'https://api.spotify.com/v1/artists/35pZsti1RSA5Zv98jAm8kX',
#       'id': '35pZsti1RSA5Zv98jAm8kX',
#       'name': 'Orpheus Chamber Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:35pZsti1RSA5Zv98jAm8kX'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2e0FIWorD7mcJNs573R4Zq'},
#     'href': 'https://api.spotify.com/v1/albums/2e0FIWorD7mcJNs573R4Zq',
#     'id': '2e0FIWorD7mcJNs573R4Zq',
#     'images': [{'height': 635,
#       'url': 'https://i.scdn.co/image/07e0f8cce6fc1fa2a30b0db65ba619d12ba8f03d',
#       'width': 640},
#      {'height': 297,
#       'url': 'https://i.scdn.co/image/df800a48680d8a5416972711ee073a1a26eef38a',
#       'width': 300},
#      {'height': 63,
#       'url': 'https://i.scdn.co/image/75397f5d1aa650b04476a88e41bf3b0dfa2f1028',
#       'width': 64}],
#     'name': 'Orpheus Chamber Orchestra - Baroque Highlights',
#     'release_date': '1990-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:2e0FIWorD7mcJNs573R4Zq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/35pZsti1RSA5Zv98jAm8kX'},
#      'href': 'https://api.spotify.com/v1/artists/35pZsti1RSA5Zv98jAm8kX',
#      'id': '35pZsti1RSA5Zv98jAm8kX',
#      'name': 'Orpheus Chamber Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:35pZsti1RSA5Zv98jAm8kX'}],
#    'disc_number': 1,
#    'duration_ms': 284000,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEF058902770'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6t7lMFHSifu9j8NPMNCv9T'},
#    'href': 'https://api.spotify.com/v1/tracks/6t7lMFHSifu9j8NPMNCv9T',
#    'id': '6t7lMFHSifu9j8NPMNCv9T',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Orchestral Suite No. 3 in D Major, BWV 1068: 2. Air',
#    'popularity': 55,
#    'preview_url': None,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6t7lMFHSifu9j8NPMNCv9T'}]}

# %%
# 곡찾기 - 곡을 찾는 기능은 api것을 사용하면 현재 받아온 곡에서 서비스를 진행할 수 없을 수 있음. 이것은 우리 데이터 안에서만 검색
sp.search('아이유')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=%EC%95%84%EC%9D%B4%EC%9C%A0&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ghBzVOTFoeKPPmyNKjVtI'},
#      'href': 'https://api.spotify.com/v1/albums/4ghBzVOTFoeKPPmyNKjVtI',
#      'id': '4ghBzVOTFoeKPPmyNKjVtI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/18a71b6fefd8bd209983ebfdf81c8c6a796d0351',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/74136ef4ee5a6b15d4d47968c1e5e53f3008f9a4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/23b2f4040c44c60c2bf6a83c2f8e5a09023ece33',
#        'width': 64}],
#      'name': 'BBIBBI',
#      'release_date': '2018-10-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4ghBzVOTFoeKPPmyNKjVtI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194426,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381801523'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4as4XEOR03oGm1STUKl6pa'},
#     'href': 'https://api.spotify.com/v1/tracks/4as4XEOR03oGm1STUKl6pa',
#     'id': '4as4XEOR03oGm1STUKl6pa',
#     'is_local': False,
#     'name': 'BBIBBI',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/58988b0d154dcdd175204a088cb33fda13b792ea?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4as4XEOR03oGm1STUKl6pa'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5V8n6fqyAPxvFTibPhQVcp'},
#      'href': 'https://api.spotify.com/v1/albums/5V8n6fqyAPxvFTibPhQVcp',
#      'id': '5V8n6fqyAPxvFTibPhQVcp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9f4f56926ab1d9377f7248b0800bf274ef7d7ad2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/60573e048c2e1ed7a95a385e5c83811ad8b14a6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/af7da5feaf5f55987ed73ff26638addde65d2af3',
#        'width': 64}],
#      'name': 'Palette',
#      'release_date': '2017-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5V8n6fqyAPxvFTibPhQVcp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 217412,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381700862'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3y7ByLZ05tluscOTRgEJ9Y'},
#     'href': 'https://api.spotify.com/v1/tracks/3y7ByLZ05tluscOTRgEJ9Y',
#     'id': '3y7ByLZ05tluscOTRgEJ9Y',
#     'is_local': False,
#     'name': 'Palette (Feat. G-DRAGON)',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d7a751b248ba11df5a13d9a043de0e634e5da06b?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3y7ByLZ05tluscOTRgEJ9Y'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4XpUIb8uuNlIWVKmgKZXC0'},
#        'href': 'https://api.spotify.com/v1/artists/4XpUIb8uuNlIWVKmgKZXC0',
#        'id': '4XpUIb8uuNlIWVKmgKZXC0',
#        'name': 'Zico',
#        'type': 'artist',
#        'uri': 'spotify:artist:4XpUIb8uuNlIWVKmgKZXC0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0aDnkPxX660ezxCWBcqzVo'},
#      'href': 'https://api.spotify.com/v1/albums/0aDnkPxX660ezxCWBcqzVo',
#      'id': '0aDnkPxX660ezxCWBcqzVo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/6f99969dc06a8aad47a09c4a00e5d32e6c6f9dbe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/b36237ff4f2bd494b25f6281485e2850195fe0b1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/4ae6a8b894820e9d30cb3c9ae2fab7020ef3032c',
#        'width': 64}],
#      'name': 'SoulMate (feat. IU)',
#      'release_date': '2018-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0aDnkPxX660ezxCWBcqzVo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4XpUIb8uuNlIWVKmgKZXC0'},
#       'href': 'https://api.spotify.com/v1/artists/4XpUIb8uuNlIWVKmgKZXC0',
#       'id': '4XpUIb8uuNlIWVKmgKZXC0',
#       'name': 'Zico',
#       'type': 'artist',
#       'uri': 'spotify:artist:4XpUIb8uuNlIWVKmgKZXC0'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 219390,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRB461800410'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1pz24zu5H9A0S1a2NKT4F0'},
#     'href': 'https://api.spotify.com/v1/tracks/1pz24zu5H9A0S1a2NKT4F0',
#     'id': '1pz24zu5H9A0S1a2NKT4F0',
#     'is_local': False,
#     'name': 'SoulMate (feat. IU)',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d4c676332d43978dff1c34227e5fed27d167e407?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1pz24zu5H9A0S1a2NKT4F0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5V8n6fqyAPxvFTibPhQVcp'},
#      'href': 'https://api.spotify.com/v1/albums/5V8n6fqyAPxvFTibPhQVcp',
#      'id': '5V8n6fqyAPxvFTibPhQVcp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9f4f56926ab1d9377f7248b0800bf274ef7d7ad2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/60573e048c2e1ed7a95a385e5c83811ad8b14a6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/af7da5feaf5f55987ed73ff26638addde65d2af3',
#        'width': 64}],
#      'name': 'Palette',
#      'release_date': '2017-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5V8n6fqyAPxvFTibPhQVcp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 253293,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381700868'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3P3UA61WRQqwCXaoFOTENd'},
#     'href': 'https://api.spotify.com/v1/tracks/3P3UA61WRQqwCXaoFOTENd',
#     'id': '3P3UA61WRQqwCXaoFOTENd',
#     'is_local': False,
#     'name': 'Through the Night',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0ac605bf88a54a00e36ec558cdfab959781ba2fd?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3P3UA61WRQqwCXaoFOTENd'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5V8n6fqyAPxvFTibPhQVcp'},
#      'href': 'https://api.spotify.com/v1/albums/5V8n6fqyAPxvFTibPhQVcp',
#      'id': '5V8n6fqyAPxvFTibPhQVcp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9f4f56926ab1d9377f7248b0800bf274ef7d7ad2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/60573e048c2e1ed7a95a385e5c83811ad8b14a6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/af7da5feaf5f55987ed73ff26638addde65d2af3',
#        'width': 64}],
#      'name': 'Palette',
#      'release_date': '2017-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5V8n6fqyAPxvFTibPhQVcp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 249241,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381700863'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/06EMBzxDm2hueehobAlMtm'},
#     'href': 'https://api.spotify.com/v1/tracks/06EMBzxDm2hueehobAlMtm',
#     'id': '06EMBzxDm2hueehobAlMtm',
#     'is_local': False,
#     'name': 'Ending Scene',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2be41b6519a0010d540cb3ae99c1bb3ea567c6d4?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:06EMBzxDm2hueehobAlMtm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56MqewtCUq5bplrqEYTVL0'},
#      'href': 'https://api.spotify.com/v1/albums/56MqewtCUq5bplrqEYTVL0',
#      'id': '56MqewtCUq5bplrqEYTVL0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/638031e627d3ea4a6d60472671b26fe5db3fa062',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/0df93144d3ba457bc1c11613838c4bee662acb89',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/40f31ab3094626fb5fcbde9a2c8bd86dd0f4a022',
#        'width': 64}],
#      'name': 'Modern Times ? Epilogue',
#      'release_date': '2013-12-20',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:56MqewtCUq5bplrqEYTVL0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 217155,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381205838'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GsRx0gPft6RmijIwMsKmG'},
#     'href': 'https://api.spotify.com/v1/tracks/0GsRx0gPft6RmijIwMsKmG',
#     'id': '0GsRx0gPft6RmijIwMsKmG',
#     'is_local': False,
#     'name': 'Friday (feat.Jang Yi-jeong of HISTORY)',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cae795e042ec6b33418dff186f9f8122d174bf91?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0GsRx0gPft6RmijIwMsKmG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5V8n6fqyAPxvFTibPhQVcp'},
#      'href': 'https://api.spotify.com/v1/albums/5V8n6fqyAPxvFTibPhQVcp',
#      'id': '5V8n6fqyAPxvFTibPhQVcp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9f4f56926ab1d9377f7248b0800bf274ef7d7ad2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/60573e048c2e1ed7a95a385e5c83811ad8b14a6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/af7da5feaf5f55987ed73ff26638addde65d2af3',
#        'width': 64}],
#      'name': 'Palette',
#      'release_date': '2017-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5V8n6fqyAPxvFTibPhQVcp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 218160,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381700865'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3h7WIL3B6nP3171zl6HWj8'},
#     'href': 'https://api.spotify.com/v1/tracks/3h7WIL3B6nP3171zl6HWj8',
#     'id': '3h7WIL3B6nP3171zl6HWj8',
#     'is_local': False,
#     'name': 'Jam Jam',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b431a5e6dbcc940e2cfbf78bd4aa5efc8673ed22?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3h7WIL3B6nP3171zl6HWj8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3rMvAe0zU0pJRnRa7Rfc1U'},
#      'href': 'https://api.spotify.com/v1/albums/3rMvAe0zU0pJRnRa7Rfc1U',
#      'id': '3rMvAe0zU0pJRnRa7Rfc1U',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ae58b3f1d6eb94713144c93fc82d8b4ffbc34bbd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/09d6ecd8b11306d9ec51412aef182c2984a0eabc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/7059dbd06b04fc22db74e67aaf89c991021dfd22',
#        'width': 64}],
#      'name': 'CHAT-SHIRE',
#      'release_date': '2015-10-23',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3rMvAe0zU0pJRnRa7Rfc1U'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194325,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381500393'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3YkDslZvvMixTwgDId0aYB'},
#     'href': 'https://api.spotify.com/v1/tracks/3YkDslZvvMixTwgDId0aYB',
#     'id': '3YkDslZvvMixTwgDId0aYB',
#     'is_local': False,
#     'name': 'Twenty-Three',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/352d4c6bfb8d51cf065686141420caf6d3b212f3?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3YkDslZvvMixTwgDId0aYB'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5V8n6fqyAPxvFTibPhQVcp'},
#      'href': 'https://api.spotify.com/v1/albums/5V8n6fqyAPxvFTibPhQVcp',
#      'id': '5V8n6fqyAPxvFTibPhQVcp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9f4f56926ab1d9377f7248b0800bf274ef7d7ad2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/60573e048c2e1ed7a95a385e5c83811ad8b14a6b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/af7da5feaf5f55987ed73ff26638addde65d2af3',
#        'width': 64}],
#      'name': 'Palette',
#      'release_date': '2017-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5V8n6fqyAPxvFTibPhQVcp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 176098,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381700861'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4NPARrLIbtMl29ZJv8ESr2'},
#     'href': 'https://api.spotify.com/v1/tracks/4NPARrLIbtMl29ZJv8ESr2',
#     'id': '4NPARrLIbtMl29ZJv8ESr2',
#     'is_local': False,
#     'name': 'dlwlrma',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2742e80916e3df2aa5ed863586c405b26bbf0a81?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4NPARrLIbtMl29ZJv8ESr2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#        'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#        'id': '3HqSLMAZ3g3d5poNaI7GOU',
#        'name': 'IU',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4WY1pPvmP9sBlVICuPxBQh'},
#      'href': 'https://api.spotify.com/v1/albums/4WY1pPvmP9sBlVICuPxBQh',
#      'id': '4WY1pPvmP9sBlVICuPxBQh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c567f4c3b76554a80f3c782bb4768dab61d8e9ad',
#        'width': 442},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/20c0ba094a67ff9e6063582a300cfa519e7a5b1d',
#        'width': 207},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/2d2e373e5642e8c3ddbeeba4cb7d3577650bed9f',
#        'width': 44}],
#      'name': 'REAL',
#      'release_date': '2010-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:4WY1pPvmP9sBlVICuPxBQh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HqSLMAZ3g3d5poNaI7GOU'},
#       'href': 'https://api.spotify.com/v1/artists/3HqSLMAZ3g3d5poNaI7GOU',
#       'id': '3HqSLMAZ3g3d5poNaI7GOU',
#       'name': 'IU',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HqSLMAZ3g3d5poNaI7GOU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 233613,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381001057'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SwZVVH9BnXtLRLi2cbFhw'},
#     'href': 'https://api.spotify.com/v1/tracks/1SwZVVH9BnXtLRLi2cbFhw',
#     'id': '1SwZVVH9BnXtLRLi2cbFhw',
#     'is_local': False,
#     'name': 'Good day',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0ef3a6e94e1e468ebc5920d384ec2850f98de8ac?cid=18036c9769a64a9488a17419863beb3b',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1SwZVVH9BnXtLRLi2cbFhw'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=%EC%95%84%EC%9D%B4%EC%9C%A0&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 147}}

# %%
sp.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-7d28a18acdbb> in <module>
# ----> 1 sp.max_get_retries(10)
#
# TypeError: 'int' object is not callable

# %%
print('number of elements in the track_id list:', len(rows))
# Out:
# number of elements in the track_id list: 9599

# %%
df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')
print("Shape of the dataset:", df_audio_features.shape)
df_audio_features.head()
# Out:
# Shape of the dataset: (9599, 18)
#    acousticness                                       analysis_url  \
# 0       0.09380  https://api.spotify.com/v1/audio-analysis/4bPQ...
# 1       0.00704  https://api.spotify.com/v1/audio-analysis/5Z01...
# 2       0.00898  https://api.spotify.com/v1/audio-analysis/2TfS...
# 3       0.02230  https://api.spotify.com/v1/audio-analysis/1PS1...
# 4       0.87200  https://api.spotify.com/v1/audio-analysis/4RCW...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.567       187613   0.795  4bPQs0PHn4xbipzdPfn6du
# 1         0.698       326467   0.732  5Z01UMMf7V1o0MzF86s6WJ
# 2         0.499       229093   0.824  2TfSHkHiFO4gRztVIkggkE
# 3         0.638       207627   0.699  1PS1QMdUqOal0ai3Gt7sDQ
# 4         0.657       232533   0.291  4RCWB3V8V0dignt99LZ8vH
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000    9    0.1140    -4.985     0       0.1340  170.060
# 1          0.000647    2    0.3590    -4.522     1       0.2660  171.431
# 2          0.000000    7    0.1630    -4.741     1       0.0794  161.977
# 3          0.000000    1    0.0917    -5.540     0       0.3840   92.939
# 4          0.000000    2    0.1140   -10.572     1       0.0293  103.973
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/4bPQs0PHn4xb...
# 1               4  https://api.spotify.com/v1/tracks/5Z01UMMf7V1o...
# 2               4  https://api.spotify.com/v1/tracks/2TfSHkHiFO4g...
# 3               4  https://api.spotify.com/v1/tracks/1PS1QMdUqOal...
# 4               4  https://api.spotify.com/v1/tracks/4RCWB3V8V0di...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:4bPQs0PHn4xbipzdPfn6du   0.6350
# 1  audio_features  spotify:track:5Z01UMMf7V1o0MzF86s6WJ   0.0689
# 2  audio_features  spotify:track:2TfSHkHiFO4gRztVIkggkE   0.6990
# 3  audio_features  spotify:track:1PS1QMdUqOal0ai3Gt7sDQ   0.6600
# 4  audio_features  spotify:track:4RCWB3V8V0dignt99LZ8vH   0.2980

# %%
df_audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9599 entries, 0 to 9598
# Data columns (total 18 columns):
# acousticness        9599 non-null float64
# analysis_url        9599 non-null object
# danceability        9599 non-null float64
# duration_ms         9599 non-null int64
# energy              9599 non-null float64
# id                  9599 non-null object
# instrumentalness    9599 non-null float64
# key                 9599 non-null int64
# liveness            9599 non-null float64
# loudness            9599 non-null float64
# mode                9599 non-null int64
# speechiness         9599 non-null float64
# tempo               9599 non-null float64
# time_signature      9599 non-null int64
# track_href          9599 non-null object
# type                9599 non-null object
# uri                 9599 non-null object
# valence             9599 non-null float64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 1.3+ MB

# %%
# df_audio_features.to_csv('SpotifyAudioFeaturesTest.csv')

# %%
columns_to_drop = ['analysis_url','track_href','type','uri']
df_audio_features.drop(columns_to_drop, axis=1,inplace=True)

df_audio_features.rename(columns={'id': 'track_id'}, inplace=True)

df_audio_features.shape
# Out:
# (9599, 14)

# %%
# merge both dataframes
# the 'inner' method will make sure that we only keep track IDs present in both datasets
df = pd.merge(df_tracks,df_audio_features,on='track_id',how='inner')
print("Shape of the dataset:", df_audio_features.shape)
df.head()
# Out:
# Shape of the dataset: (9599, 14)
#            artist_name                                track_name  \
# 0  Panic! At The Disco                I Write Sins Not Tragedies
# 1               Eminem  Lose Yourself - From "8 Mile" Soundtrack
# 2         Fall Out Boy                    Sugar, We're Goin Down
# 3           Kanye West                               Gold Digger
# 4      Plain White T's                         Hey There Delilah
#
#                  track_id  popularity  \
# 0  4bPQs0PHn4xbipzdPfn6du          76
# 1  5Z01UMMf7V1o0MzF86s6WJ          80
# 2  2TfSHkHiFO4gRztVIkggkE          78
# 3  1PS1QMdUqOal0ai3Gt7sDQ          78
# 4  4RCWB3V8V0dignt99LZ8vH          79
#
#                                                  url  \
# 0  https://open.spotify.com/track/4bPQs0PHn4xbipz...
# 1  https://open.spotify.com/track/5Z01UMMf7V1o0Mz...
# 2  https://open.spotify.com/track/2TfSHkHiFO4gRzt...
# 3  https://open.spotify.com/track/1PS1QMdUqOal0ai...
# 4  https://open.spotify.com/track/4RCWB3V8V0dignt...
#
#                                               images        date  \
# 0  https://i.scdn.co/image/76c86f33b0ffc852e4141e...  2005-09-27
# 1  https://i.scdn.co/image/77eb7c17cafe5503fc12e9...  2005-12-06
# 2  https://i.scdn.co/image/63a37f32006eab70bd58c8...  2005-01-01
# 3  https://i.scdn.co/image/92db1dda6ed503723c89c3...  2005-09-30
# 4  https://i.scdn.co/image/3a3e50577a99bfca93494b...  2005-01-01
#
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0       0.09380         0.567       187613   0.795          0.000000    9
# 1       0.00704         0.698       326467   0.732          0.000647    2
# 2       0.00898         0.499       229093   0.824          0.000000    7
# 3       0.02230         0.638       207627   0.699          0.000000    1
# 4       0.87200         0.657       232533   0.291          0.000000    2
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0    0.1140    -4.985     0       0.1340  170.060               4   0.6350
# 1    0.3590    -4.522     1       0.2660  171.431               4   0.0689
# 2    0.1630    -4.741     1       0.0794  161.977               4   0.6990
# 3    0.0917    -5.540     0       0.3840   92.939               4   0.6600
# 4    0.1140   -10.572     1       0.0293  103.973               4   0.2980

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9599 entries, 0 to 9598
# Data columns (total 20 columns):
# artist_name         9599 non-null object
# track_name          9599 non-null object
# track_id            9599 non-null object
# popularity          9599 non-null int64
# url                 9599 non-null object
# images              9599 non-null object
# date                9599 non-null object
# acousticness        9599 non-null float64
# danceability        9599 non-null float64
# duration_ms         9599 non-null int64
# energy              9599 non-null float64
# instrumentalness    9599 non-null float64
# key                 9599 non-null int64
# liveness            9599 non-null float64
# loudness            9599 non-null float64
# mode                9599 non-null int64
# speechiness         9599 non-null float64
# tempo               9599 non-null float64
# time_signature      9599 non-null int64
# valence             9599 non-null float64
# dtypes: float64(9), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
df[df.duplicated(subset=['artist_name','track_name'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [artist_name, track_name, track_id, popularity, url, images, date, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, time_signature, valence]
# Index: []
