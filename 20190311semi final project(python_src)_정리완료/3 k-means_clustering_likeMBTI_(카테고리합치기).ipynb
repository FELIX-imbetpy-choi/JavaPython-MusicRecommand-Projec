# %%
# Module
import pandas as pd

# %%
song = pd.read_csv('./data/20190305_clust_spotify_allsong_ver3.csv')
song.head()
# Out:
#    seq   artist_name           track_name                track_id  popularity  \
# 0    1   Linkin Park           In The End  60a0Rd6pjrkxjPbaKzXjfq          83
# 1    2  3 Doors Down           Kryptonite  6ZOBP3NvffbU4SZcrnt1k6          78
# 2    3        Eminem  The Real Slim Shady  3yfqSUWxFvZELEM4PmlwIR          78
# 3    4       OutKast          Ms. Jackson  0I3q5fE6wg7LIfHGngUTnV          77
# 4    5      Coldplay               Yellow  3AJwUDP919kvQ9QcozQPxg          81
#
#                                                  url  \
# 0  https://open.spotify.com/track/60a0Rd6pjrkxjPb...
# 1  https://open.spotify.com/track/6ZOBP3NvffbU4SZ...
# 2  https://open.spotify.com/track/3yfqSUWxFvZELEM...
# 3  https://open.spotify.com/track/0I3q5fE6wg7LIfH...
# 4  https://open.spotify.com/track/3AJwUDP919kvQ9Q...
#
#                                               images        date  \
# 0  https://i.scdn.co/image/66ff51342a9b250bf5b998...  2000-10-24
# ...

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169264 entries, 0 to 169263
# Data columns (total 33 columns):
# seq                      169264 non-null int64
# artist_name              169264 non-null object
# track_name               169264 non-null object
# track_id                 169264 non-null object
# popularity               169264 non-null int64
# url                      169264 non-null object
# images                   169264 non-null object
# date                     169264 non-null object
# acousticness             169264 non-null float64
# danceability             169264 non-null float64
# duration_ms              169264 non-null float64
# energy                   169264 non-null float64
# instrumentalness         169264 non-null float64
# key                      169264 non-null int64
# liveness                 169264 non-null float64
# loudness                 169264 non-null float64
# mode                     169264 non-null int64
# ...

# %%
song['category'] = song['clst_loudness'].astype('str') + song['clst_tempo'].astype('str') \
                 + song['clst_acoustic'].astype('str') + song['clst_danceability'].astype('str') \
                 + song['clst_instrumentalness'].astype('str') + song['clst_speechiness'].astype('str') \
                 + song['clst_valence'].astype('str')

# %%
song.head()
# Out:
#    seq   artist_name           track_name                track_id  popularity  \
# 0    1   Linkin Park           In The End  60a0Rd6pjrkxjPbaKzXjfq          83
# 1    2  3 Doors Down           Kryptonite  6ZOBP3NvffbU4SZcrnt1k6          78
# 2    3        Eminem  The Real Slim Shady  3yfqSUWxFvZELEM4PmlwIR          78
# 3    4       OutKast          Ms. Jackson  0I3q5fE6wg7LIfHGngUTnV          77
# 4    5      Coldplay               Yellow  3AJwUDP919kvQ9QcozQPxg          81
#
#                                                  url  \
# 0  https://open.spotify.com/track/60a0Rd6pjrkxjPb...
# 1  https://open.spotify.com/track/6ZOBP3NvffbU4SZ...
# 2  https://open.spotify.com/track/3yfqSUWxFvZELEM...
# 3  https://open.spotify.com/track/0I3q5fE6wg7LIfH...
# 4  https://open.spotify.com/track/3AJwUDP919kvQ9Q...
#
#                                               images        date  \
# 0  https://i.scdn.co/image/66ff51342a9b250bf5b998...  2000-10-24
# ...

# %%
song['category'].unique()
# Out:
# array(['1001000', '1001001', '1002001', '1002011', '1201000', '1201001',
#        '1012001', '1100001', '1002010', '1111001', '1202001', '1102001',
#        '1122001', '1121000', '1101000', '1021001', '1202011', '1011001',
#        '1101001', '1001011', '1100000', '1200000', '1211000', '1112001',
#        '1000000', '0020200', '1101010', '1111000', '0112001', '1001010',
#        '1012000', '1010001', '1021000', '1020000', '1102101', '1102201',
#        '1001101', '1000001', '1102011', '0121200', '1002000', '1221001',
#        '1120000', '0021001', '1102000', '1121200', '1200010', '1011000',
#        '1101200', '1220001', '0022001', '1221200', '1012201', '1121001',
#        '1110000', '0110000', '1021101', '0022000', '1101201', '1200001',
#        '1112011', '1101011', '0020000', '1002101', '1221201', '1001200',
#        '1211001', '1010200', '0120000', '0121001', '0121000', '0001001',
#        '0120200', '0111000', '0201000', '1212001', '1112000', '1210001',
# ...

# %%
len(song['category'].unique())
# Out:
# 713

# %%
song.to_csv('./data/song.csv',header=True, index=False, encoding='utf-8')
